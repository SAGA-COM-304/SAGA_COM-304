# %%
# Cell 1 — Imports & configuration
import os
import shutil
import subprocess
import time
import pandas as pd
from yt_dlp import YoutubeDL

OUTPUT_DIR   = "data_set_try1/videos"                             # dossier de sortie
CSV_LABELS   = "data_set_try1/dataset/labels_semantic_clusters.csv"
CSV_DATA     = "data_set_try1/dataset/vggsound.csv"
CLUSTER      = '3'                                  # numéro de cluster
DURATION_SEC = 10                                   # durée du clip en secondes

# Vérifions qu’on a bien ffmpeg dispo
if shutil.which("ffmpeg") is None:
    raise RuntimeError("⚠️ ffmpeg n'est pas installé — indispensable pour ce script.")

# %%
# Cell 2 — Fonctions utilitaires
def sec_to_timestamp(s: int) -> str:
    """Convertit un entier de secondes en 'HH:MM:SS'."""
    return time.strftime("%H:%M:%S", time.gmtime(s))

def download_segment_fast(video_id: str, start_sec: int, duration: int, dest_folder: str):
    """
    1) Récupère l’URL du flux MP4 (360p, conteneur mp4).
    2) Lance ffmpeg avec -ss et -t pour ne tirer que la portion souhaitée.
    """
    os.makedirs(dest_folder, exist_ok=True)
    url = f"https://www.youtube.com/watch?v={video_id}"

    # 1) Extraction de l’URL directe du flux MP4 (audio+vidéo) H264≤360p
    ydl_opts = {
        'format': 'best[height<=360][ext=mp4]',
        'quiet': True,
        'skip_download': True,
    }
    with YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(url, download=False)
        stream_url = info['url']

    # 2) Construction du nom et des timestamps
    t0 = sec_to_timestamp(start_sec)
    output_name = f"{video_id}_{start_sec}s.mp4"
    output_path = os.path.join(dest_folder, output_name)

    # 3) Appel ffmpeg : -ss avant -i pour seek rapide, -t pour durée, -c copy pour pas ré-encoder
    cmd = [
        'ffmpeg',
        '-ss', t0,
        '-i', stream_url,
        '-t', str(duration),
        '-c', 'copy',
        output_path
    ]
    subprocess.run(cmd, check=True)

def download_segment_crop256(video_id: str, start_sec: int, duration: int, dest_folder: str):
    """
    1) Récupère l’URL du flux MP4 (360p).
    2) Coupe le segment [start_sec, start_sec+duration].
    3) Croppe en 256×256 centré.
    4) Sort en MP4 (H.264+AAC).
    """
    os.makedirs(dest_folder, exist_ok=True)
    url = f"https://www.youtube.com/watch?v={video_id}"

    # Extraction de l’URL directe du flux MP4
    ydl_opts = {'format': 'best[height<=360][ext=mp4]', 'quiet': True, 'skip_download': True}
    with YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(url, download=False)
        stream_url = info['url']

    # Timestamp de début
    t0 = sec_to_timestamp(start_sec)
    output_name = f"{video_id}_{start_sec}s_256crop.mp4"
    output_path = os.path.join(dest_folder, output_name)

    # ffmpeg : -ss avant -i pour seek rapide, -t pour durée, -vf pour crop, 
    # -c:v libx264 pour encoder, -preset veryfast pour vitesse, -crf 23 qualité raisonnable, -c:a copy
    cmd = [
        'ffmpeg',
        '-ss', t0,
        '-i', stream_url,
        '-t', str(duration),
        '-vf', 'crop=256:256:(in_w-256)/2:(in_h-256)/2',
        '-c:v', 'libx264',
        '-preset', 'veryfast',
        '-crf', '23',
        '-c:a', 'copy',
        output_path
    ]
    subprocess.run(cmd, check=True)

# %%
# Cell 3 — Lecture & filtrage du dataset
labels_df = pd.read_csv(CSV_LABELS, header=None,
                        names=['label','count','cluster'])
used_labels = labels_df[labels_df['cluster']==CLUSTER]['label'].values

data_df = pd.read_csv(CSV_DATA, header=None,
                      names=['video_id','start_sec','label','split'])
sub_df = data_df[data_df['label'].isin(used_labels)].sample(10, random_state=42)

# %%
labels_df
# Out:
#                                  label  count  cluster
# 0                                label  count  cluster
# 1                    fireworks banging   1050        1
# 2                          tap dancing   1050        2
# 3    motorboat, speedboat acceleration   1050        0
# 4                     playing trombone   1050        2
# ..                                 ...    ...      ...
# 306                     snake rattling    199        1
# 307                      zebra braying    199        1
# 308                  playing castanets    199        3
# 309                         cow lowing    199        1
# 310                           air horn    197        1
#
# [311 rows x 3 columns]

# %%
# Cell 4 — Boucle de téléchargement
for vid, start, label, split in sub_df.itertuples(index=False):
    real_end = min(start + DURATION_SEC, start + DURATION_SEC)  # juste pour l'affichage
    print(f"▶️ {vid} @ {start}s → +{DURATION_SEC}s …")
    try:
        download_segment_crop256(vid, int(start), DURATION_SEC, OUTPUT_DIR)
    except Exception as e:
        print(f"⚠️ Erreur pour {vid}@{start}s : {e}")

print("✅ Tous les segments (10 s) sont prêts en MP4 dans", OUTPUT_DIR)
# Out:
# ▶️ 5PVKgUGg0LQ @ 450s → +10s …
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with clang version 17.0.6
#   configuration: --prefix=/opt/anaconda3/envs/dataloader --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1728332276747/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1728332276747/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr1---sn-nfpuji-1gil.googlevideo.com/videoplayback?expire=1745868010&ei=ioAPaIeeD7mI6dsP-5vZ0QI&ip=2001%3A620%3A618%3A5c0%3A2%3A80b3%3A0%3A3d3&id=o-AKcK4nWIzE4admI3X8cpGeeYHVuTUIkzyphLgxMnrUki&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1745846410%2C&mh=7z&mm=31%2C29&mn=sn-nfpuji-1gil%2Csn-1gi7znek&ms=au%2Crdu&mv=m&mvi=1&pcm2cms=yes&pl=32&rms=au%2Cau&initcwndbps=4433750&bui=AecWEAZBbSZMx-pfThANR6olFw4VXGDsy-7AHtTCSqpxfwbN5q9Btw3_Rc07FEvypmaEUCPcw-qhQKrG&vprv=1&svpuc=1&mime=video%2Fmp4&ns=kiCxlk17Q68QrqIrcyknZroQ&rqh=1&cnr=14&ratebypass=yes&dur=664.926&lmt=1743737791279412&mt=1745845981&fvip=1&lmw=1&c=TVHTML5&sefc=1&txp=5438534&n=aJ2v8YdF3HMGaQ&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cbui%2Cvprv%2Csvpuc%2Cmime%2Cns%2Crqh%2Ccnr%2Cratebypass%2Cdur%2Clmt&sig=AJfQdSswRAIgGwn5Q9fDLcGH5Rbvw7Wa-7NiBLIq4vzKnruLTkSO06cCIHMkxyEoGcTAcLmhi0EGjPW_6l0SB81Ux7Ze6oZ42Jml&lsparams=met%2Cmh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Crms%2Cinitcwndbps&lsig=ACuhMU0wRQIhALJnketd5t9L6VZSuRCDhs2IsT_AStNRnvp2OcNCkihXAiAjyPFZt86olrH4B9Y9YkQrirvzkP0HJTV22aeaeICG7A%3D%3D':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2024-03-27T01:40:42.000000Z
#   Duration: 00:11:04.88, start: 0.000000, bitrate: 372 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360 [SAR 1:1 DAR 16:9], 240 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#       Metadata:
#         creation_time   : 2024-03-27T01:40:42.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 03/26/2024.
#         vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#       Metadata:
#         creation_time   : 2024-03-27T01:40:42.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 03/26/2024.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x127719640] using SAR=1/1
# [libx264 @ 0x127719640] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x127719640] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x127719640] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=1 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=2 psy=1 psy_rd=1.00:0.00 mixed_ref=0 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=0 threads=8 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=10 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'data_set_try1/videos/5PVKgUGg0LQ_450s_256crop.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf61.7.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 256x256 [SAR 1:1 DAR 1:1], q=2-31, 29.97 fps, 30k tbn (default)
#       Metadata:
#         creation_time   : 2024-03-27T01:40:42.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 03/26/2024.
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#       Metadata:
#         creation_time   : 2024-03-27T01:40:42.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 03/26/2024.
#         vendor_id       : [0][0][0][0]
# [out#0/mp4 @ 0x127718050] video:156KiB audio:227KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 3.319953%
# frame=  300 fps=0.0 q=-1.0 Lsize=     395KiB time=00:00:09.94 bitrate= 325.6kbits/s speed=16.6x
# [libx264 @ 0x127719640] frame I:2     Avg QP:21.69  size:  5876
# [libx264 @ 0x127719640] frame P:112   Avg QP:25.22  size:   941
# [libx264 @ 0x127719640] frame B:186   Avg QP:29.02  size:   223
# [libx264 @ 0x127719640] consecutive B-frames: 11.7% 14.0%  9.0% 65.3%
# [libx264 @ 0x127719640] mb I  I16..4: 27.7% 15.8% 56.4%
# [libx264 @ 0x127719640] mb P  I16..4:  4.8%  4.5%  1.9%  P16..4: 31.6%  9.2%  5.1%  0.0%  0.0%    skip:42.8%
# [libx264 @ 0x127719640] mb B  I16..4:  1.0%  1.1%  0.2%  B16..8:  7.3%  2.9%  0.4%  direct: 3.0%  skip:84.1%  L0:40.6% L1:45.3% BI:14.1%
# [libx264 @ 0x127719640] 8x8 transform intra:39.4% inter:27.7%
# [libx264 @ 0x127719640] coded y,uvDC,uvAC intra: 54.0% 56.2% 28.9% inter: 7.0% 5.3% 0.6%
# [libx264 @ 0x127719640] i16 v,h,dc,p: 32% 56%  7%  5%
# [libx264 @ 0x127719640] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 33% 38% 14%  2%  2%  3%  3%  3%  3%
# [libx264 @ 0x127719640] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 50% 13%  1%  3%  2%  2%  2%  3%
# [libx264 @ 0x127719640] i8c dc,h,v,p: 36% 32% 27%  4%
# [libx264 @ 0x127719640] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x127719640] kb/s:126.86
# ▶️ wd2RVda164o @ 30s → +10s …
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with clang version 17.0.6
#   configuration: --prefix=/opt/anaconda3/envs/dataloader --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1728332276747/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1728332276747/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr3---sn-nfpuji-1gil.googlevideo.com/videoplayback?expire=1745868013&ei=jYAPaI2XGIC26dsPq9ex4QE&ip=2001%3A620%3A618%3A5c0%3A2%3A80b3%3A0%3A3d3&id=o-AG3LCn1F-luAe381AJOg8HGD0FOeAHI0KfJdWFTdVtuc&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1745846413%2C&mh=gA&mm=31%2C29&mn=sn-nfpuji-1gil%2Csn-1giz7n7l&ms=au%2Crdu&mv=m&mvi=3&pcm2cms=yes&pl=32&rms=au%2Cau&initcwndbps=4433750&bui=AecWEAYtWfLmwuznkFjDIuiaIXNTxZRBfFjuC0CryUyF70A-zggkqhaHMLGWlZ6wKfnAYOdrxChqQ2zl&vprv=1&svpuc=1&mime=video%2Fmp4&ns=9W6oONEoxetS-7jw6_McKaEQ&rqh=1&cnr=14&ratebypass=yes&dur=374.166&lmt=1661826025439816&mt=1745845981&fvip=1&lmw=1&c=TVHTML5&sefc=1&txp=1318224&n=z9I6s1yGtAqJBg&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cbui%2Cvprv%2Csvpuc%2Cmime%2Cns%2Crqh%2Ccnr%2Cratebypass%2Cdur%2Clmt&sig=AJfQdSswRQIge7HAhEaEwPztTUgbmlAPsZWMcu3dn4gk_3YQ-AhQ4lYCIQDDxZcPdnKRueJDJcJDD9CKZmk5hy8iEH83F8W7UidCEQ%3D%3D&lsparams=met%2Cmh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Crms%2Cinitcwndbps&lsig=ACuhMU0wRQIhAKUfAkkgPa9DhAMBQXvCXfFRJNIer_vxf0cDNEOPNXrMAiBjnojJ6W9R5oXQqE3uNkQhEDm99SJN95HDoIyA4IumYQ%3D%3D':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2021-08-01T15:28:40.000000Z
#   Duration: 00:06:14.12, start: 0.000000, bitrate: 718 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360 [SAR 1:1 DAR 16:9], 586 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         creation_time   : 2021-08-01T15:28:40.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 08/01/2021.
#         vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#       Metadata:
#         creation_time   : 2021-08-01T15:28:40.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 08/01/2021.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x124f96300] using SAR=1/1
# [libx264 @ 0x124f96300] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x124f96300] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x124f96300] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=1 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=2 psy=1 psy_rd=1.00:0.00 mixed_ref=0 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=0 threads=8 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=10 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'data_set_try1/videos/wd2RVda164o_30s_256crop.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf61.7.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 256x256 [SAR 1:1 DAR 1:1], q=2-31, 30 fps, 15360 tbn (default)
#       Metadata:
#         creation_time   : 2021-08-01T15:28:40.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 08/01/2021.
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#       Metadata:
#         creation_time   : 2021-08-01T15:28:40.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 08/01/2021.
#         vendor_id       : [0][0][0][0]
# [out#0/mp4 @ 0x124f97c00] video:298KiB audio:209KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 2.494503%
# frame=  300 fps=0.0 q=-1.0 Lsize=     520KiB time=00:00:09.93 bitrate= 428.7kbits/s speed=33.8x
# [libx264 @ 0x124f96300] frame I:2     Avg QP:23.16  size: 13757
# [libx264 @ 0x124f96300] frame P:86    Avg QP:26.66  size:  1771
# [libx264 @ 0x124f96300] frame B:212   Avg QP:31.39  size:   589
# [libx264 @ 0x124f96300] consecutive B-frames:  3.3%  6.0%  4.0% 86.7%
# [libx264 @ 0x124f96300] mb I  I16..4:  0.4%  4.5% 95.1%
# [libx264 @ 0x124f96300] mb P  I16..4:  0.2%  1.4%  6.3%  P16..4: 20.9%  5.0%  7.4%  0.0%  0.0%    skip:58.8%
# [libx264 @ 0x124f96300] mb B  I16..4:  0.0%  0.1%  0.2%  B16..8:  8.6%  7.5%  3.1%  direct: 3.4%  skip:77.1%  L0:36.1% L1:35.8% BI:28.1%
# [libx264 @ 0x124f96300] 8x8 transform intra:16.5% inter:11.5%
# [libx264 @ 0x124f96300] coded y,uvDC,uvAC intra: 94.0% 81.1% 47.7% inter: 12.3% 6.2% 1.1%
# [libx264 @ 0x124f96300] i16 v,h,dc,p: 31% 16% 33% 20%
# [libx264 @ 0x124f96300] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 18% 16%  4%  8%  6%  7%  8% 10%
# [libx264 @ 0x124f96300] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 15% 18%  5% 11%  8%  6%  8%  9%
# [libx264 @ 0x124f96300] i8c dc,h,v,p: 46% 20% 25%  9%
# [libx264 @ 0x124f96300] Weighted P-Frames: Y:1.2% UV:0.0%
# [libx264 @ 0x124f96300] kb/s:243.75
# ▶️ IpHCwR7ACjI @ 189s → +10s …
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with clang version 17.0.6
#   configuration: --prefix=/opt/anaconda3/envs/dataloader --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1728332276747/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1728332276747/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr2---sn-nfpuji-1gil.googlevideo.com/videoplayback?expire=1745868016&ei=kIAPaMH2BaS26dsP14zFgQQ&ip=2001%3A620%3A618%3A5c0%3A2%3A80b3%3A0%3A3d3&id=o-AOhqhWDrSauIKhHLMsqHzz_Pt7TGFcCzOI01ghQG6tj5&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1745846416%2C&mh=rB&mm=31%2C29&mn=sn-nfpuji-1gil%2Csn-1gi7znek&ms=au%2Crdu&mv=m&mvi=2&pcm2cms=yes&pl=32&rms=au%2Cau&initcwndbps=4433750&bui=AecWEAaujzl_29HnHt_6m5cNxr5omDj3rLFAKe1Glew7n-v-oLGMz0rtYCnxfNPAAgOFpifHMyKalmC9&vprv=1&svpuc=1&mime=video%2Fmp4&ns=ALVp4dW4ZFaeIOtCn2PR2dEQ&rqh=1&cnr=14&ratebypass=yes&dur=1041.600&lmt=1738736159285028&mt=1745845981&fvip=2&lmw=1&c=TVHTML5&sefc=1&txp=8208224&n=XtYbpg68hlCC0A&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cbui%2Cvprv%2Csvpuc%2Cmime%2Cns%2Crqh%2Ccnr%2Cratebypass%2Cdur%2Clmt&lsparams=met%2Cmh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Crms%2Cinitcwndbps&lsig=ACuhMU0wRgIhAOUTUhakHh9iFTTdHH-mZgcG7XvnBdSjXXWbVcWpUl2LAiEAl1jcFazW5QxX_N649Q4PQZ1MuNZf81mqRiFtt5mbggs%3D&sig=AJfQdSswRAIgUOafLbsGllZlgAEJYdiIwS6yhdKHtuxeO4HnoLDh7FICIDFpnxbCsZJSquP03Q3DWnOpWLPJf5NTDxGb3PLZ4_n-':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2025-02-05T06:05:44.000000Z
#     encoder         : Google
#   Duration: 00:17:21.55, start: 0.000000, bitrate: 587 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360 [SAR 1:1 DAR 16:9], 455 kb/s, 24 fps, 24 tbr, 12288 tbn (default)
#       Metadata:
#         creation_time   : 2025-02-05T06:05:44.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 02/04/2025.
#         vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#       Metadata:
#         creation_time   : 2025-02-05T06:05:44.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 02/04/2025.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x13e0059a0] using SAR=1/1
# [libx264 @ 0x13e0059a0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x13e0059a0] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x13e0059a0] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=1 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=2 psy=1 psy_rd=1.00:0.00 mixed_ref=0 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=0 threads=8 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=10 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'data_set_try1/videos/IpHCwR7ACjI_189s_256crop.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf61.7.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 256x256 [SAR 1:1 DAR 1:1], q=2-31, 24 fps, 12288 tbn (default)
#       Metadata:
#         creation_time   : 2025-02-05T06:05:44.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 02/04/2025.
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#       Metadata:
#         creation_time   : 2025-02-05T06:05:44.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 02/04/2025.
#         vendor_id       : [0][0][0][0]
# [out#0/mp4 @ 0x13e004b20] video:254KiB audio:178KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 2.128800%
# frame=  240 fps=0.0 q=-1.0 Lsize=     441KiB time=00:00:09.91 bitrate= 364.2kbits/s speed=24.4x
# [libx264 @ 0x13e0059a0] frame I:3     Avg QP:22.42  size:  3674
# [libx264 @ 0x13e0059a0] frame P:88    Avg QP:24.30  size:  1760
# [libx264 @ 0x13e0059a0] frame B:149   Avg QP:27.01  size:   627
# [libx264 @ 0x13e0059a0] consecutive B-frames:  7.9% 24.2% 11.2% 56.7%
# [libx264 @ 0x13e0059a0] mb I  I16..4: 14.1% 44.7% 41.3%
# [libx264 @ 0x13e0059a0] mb P  I16..4: 11.9% 22.7%  6.6%  P16..4: 23.8% 15.4%  8.7%  0.0%  0.0%    skip:11.0%
# [libx264 @ 0x13e0059a0] mb B  I16..4:  2.2%  1.9%  0.3%  B16..8: 29.4% 13.3%  1.7%  direct: 5.4%  skip:45.8%  L0:33.5% L1:49.3% BI:17.2%
# [libx264 @ 0x13e0059a0] 8x8 transform intra:52.9% inter:19.0%
# [libx264 @ 0x13e0059a0] coded y,uvDC,uvAC intra: 47.2% 56.6% 19.4% inter: 11.8% 12.2% 0.6%
# [libx264 @ 0x13e0059a0] i16 v,h,dc,p: 33% 37% 21%  8%
# [libx264 @ 0x13e0059a0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 33% 27%  3%  6%  4%  5%  3%  5%
# [libx264 @ 0x13e0059a0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 23% 19%  3% 12%  7%  7%  5%  6%
# [libx264 @ 0x13e0059a0] i8c dc,h,v,p: 54% 24% 17%  5%
# [libx264 @ 0x13e0059a0] Weighted P-Frames: Y:3.4% UV:1.1%
# [libx264 @ 0x13e0059a0] kb/s:207.44
# ▶️ 9Qttcz2JRlI @ 282s → +10s …
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with clang version 17.0.6
#   configuration: --prefix=/opt/anaconda3/envs/dataloader --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1728332276747/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1728332276747/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr3---sn-nfpuji-1gil.googlevideo.com/videoplayback?expire=1745868019&ei=k4APaPnxFouG6dsPpse_mA4&ip=2001%3A620%3A618%3A5c0%3A2%3A80b3%3A0%3A3d3&id=o-ANg8yZ7mXgI8I5sy2vJ6aLThgC7g044EhHpD16IlS-Cq&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1745846419%2C&mh=q5&mm=31%2C29&mn=sn-nfpuji-1gil%2Csn-1giz7n7l&ms=au%2Crdu&mv=m&mvi=3&pcm2cms=yes&pl=32&rms=au%2Cau&initcwndbps=4433750&bui=AecWEAZ4n_1msHPCvrtgvJgY8XRlSPcUtnAXF-fKp21ASe0bIFecKhUWVN8fKked0SLAINiKr_kYv9Jj&vprv=1&svpuc=1&mime=video%2Fmp4&ns=xU9YF9i2xy4bPYiePAa-g8QQ&rqh=1&cnr=14&ratebypass=yes&dur=321.108&lmt=1706860381100955&mt=1745845981&fvip=4&lmw=1&c=TVHTML5&sefc=1&txp=2218224&n=he6x8qq_-e_xLw&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cbui%2Cvprv%2Csvpuc%2Cmime%2Cns%2Crqh%2Ccnr%2Cratebypass%2Cdur%2Clmt&sig=AJfQdSswRQIgFMlijAJpoyN88oHX2n3DRFouvaMjjza_v2ToObwiYl8CIQCnyG6NSrBiAlpcWWJTPZZPRE5_TbTpgPkN92HdEjzuxw%3D%3D&lsparams=met%2Cmh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Crms%2Cinitcwndbps&lsig=ACuhMU0wRQIgI3vy6wStr-8g2BJD3yVKncQUDEM65P_qkeb2hKJfCO8CIQDsDX2PkTycMEIeYQjQDygMk6j7xIeWKVTnT5xqys4Rsg%3D%3D':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2024-02-02T07:47:50.000000Z
#   Duration: 00:05:21.04, start: 0.000000, bitrate: 352 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360 [SAR 1:1 DAR 16:9], 221 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         creation_time   : 2024-02-02T07:47:50.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 02/01/2024.
#         vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#       Metadata:
#         creation_time   : 2024-02-02T07:47:50.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 02/01/2024.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x14d806030] using SAR=1/1
# [libx264 @ 0x14d806030] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x14d806030] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x14d806030] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=1 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=2 psy=1 psy_rd=1.00:0.00 mixed_ref=0 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=0 threads=8 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=10 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'data_set_try1/videos/9Qttcz2JRlI_282s_256crop.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf61.7.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 256x256 [SAR 1:1 DAR 1:1], q=2-31, 30 fps, 15360 tbn (default)
#       Metadata:
#         creation_time   : 2024-02-02T07:47:50.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 02/01/2024.
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#       Metadata:
#         creation_time   : 2024-02-02T07:47:50.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 02/01/2024.
#         vendor_id       : [0][0][0][0]
# [out#0/mp4 @ 0x14da05200] video:142KiB audio:230KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 3.430271%
# frame=  300 fps=0.0 q=-1.0 Lsize=     385KiB time=00:00:09.93 bitrate= 317.3kbits/s speed=17.2x
# [libx264 @ 0x14d806030] frame I:3     Avg QP:22.92  size:  3124
# [libx264 @ 0x14d806030] frame P:104   Avg QP:24.33  size:   940
# [libx264 @ 0x14d806030] frame B:193   Avg QP:26.72  size:   193
# [libx264 @ 0x14d806030] consecutive B-frames:  8.3% 14.0% 11.0% 66.7%
# [libx264 @ 0x14d806030] mb I  I16..4: 10.5% 52.5% 37.0%
# [libx264 @ 0x14d806030] mb P  I16..4:  5.0% 11.6%  2.2%  P16..4: 21.3% 12.1%  5.6%  0.0%  0.0%    skip:42.2%
# [libx264 @ 0x14d806030] mb B  I16..4:  0.4%  0.5%  0.0%  B16..8: 10.1%  3.8%  0.5%  direct: 1.6%  skip:82.9%  L0:40.8% L1:43.6% BI:15.6%
# [libx264 @ 0x14d806030] 8x8 transform intra:60.0% inter:22.1%
# [libx264 @ 0x14d806030] coded y,uvDC,uvAC intra: 49.3% 34.4% 7.3% inter: 4.7% 3.0% 0.2%
# [libx264 @ 0x14d806030] i16 v,h,dc,p: 26% 42% 12% 20%
# [libx264 @ 0x14d806030] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 53% 18%  1%  2%  2%  4%  1%  4%
# [libx264 @ 0x14d806030] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 39% 15%  2%  5%  3%  5%  2%  8%
# [libx264 @ 0x14d806030] i8c dc,h,v,p: 53% 28% 16%  3%
# [libx264 @ 0x14d806030] Weighted P-Frames: Y:2.9% UV:1.9%
# [libx264 @ 0x14d806030] kb/s:115.49
# ▶️ wwxXsszinio @ 105s → +10s …
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with clang version 17.0.6
#   configuration: --prefix=/opt/anaconda3/envs/dataloader --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1728332276747/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1728332276747/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr1---sn-nfpuji-1gil.googlevideo.com/videoplayback?expire=1745868022&ei=loAPaOe7Eu2N6dsP1_ifsQw&ip=2001%3A620%3A618%3A5c0%3A2%3A80b3%3A0%3A3d3&id=o-AHH-8KZuocgSE5ZBcr_LK2H-F211UMQdPass5YKXDQo6&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1745846422%2C&mh=fh&mm=31%2C29&mn=sn-nfpuji-1gil%2Csn-1giz7n7l&ms=au%2Crdu&mv=m&mvi=1&pcm2cms=yes&pl=32&rms=au%2Cau&initcwndbps=4433750&bui=AecWEAa7a9PBSr-H7FxFJhr0DwSIKE_ZUxvpZV6niNLR0CppyABsg3w_XeFKWagiOcpKQVCXSPsPeTSt&vprv=1&svpuc=1&mime=video%2Fmp4&ns=w8PdiaVjkDS1Au5BtFUJdCwQ&rqh=1&cnr=14&ratebypass=yes&dur=155.202&lmt=1673894712059340&mt=1745845981&fvip=4&lmw=1&c=TVHTML5&sefc=1&txp=6219224&n=8SJq7jawyDLlaQ&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cbui%2Cvprv%2Csvpuc%2Cmime%2Cns%2Crqh%2Ccnr%2Cratebypass%2Cdur%2Clmt&sig=AJfQdSswRgIhAK2KMhUMThC88FrsDJISCF_XHSPr_WvtXr0fqPYBMni7AiEA2uJT6EZszy9e7aKBOa4n1sxUJMHo0jzJJIym8M4DDjQ%3D&lsparams=met%2Cmh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Crms%2Cinitcwndbps&lsig=ACuhMU0wRAIgSeN3d5KhMhJvjCAZStJuXTTVtx6zdRm1CEGkJz3_PisCIFpRmOmEzn0vEsD4UlaOq36OMQLFW_6f6vCkxedZhxvr':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2023-01-16T18:29:36.000000Z
#   Duration: 00:02:35.16, start: 0.000000, bitrate: 676 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360 [SAR 1:1 DAR 16:9], 544 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#       Metadata:
#         creation_time   : 2023-01-16T18:29:36.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 01/16/2023.
#         vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#       Metadata:
#         creation_time   : 2023-01-16T18:29:36.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 01/16/2023.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x155ea16c0] using SAR=1/1
# [libx264 @ 0x155ea16c0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x155ea16c0] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x155ea16c0] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=1 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=2 psy=1 psy_rd=1.00:0.00 mixed_ref=0 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=0 threads=8 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=10 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'data_set_try1/videos/wwxXsszinio_105s_256crop.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf61.7.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 256x256 [SAR 1:1 DAR 1:1], q=2-31, 29.97 fps, 30k tbn (default)
#       Metadata:
#         creation_time   : 2023-01-16T18:29:36.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 01/16/2023.
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#       Metadata:
#         creation_time   : 2023-01-16T18:29:36.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 01/16/2023.
#         vendor_id       : [0][0][0][0]
# [out#0/mp4 @ 0x155eb1aa0] video:519KiB audio:213KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.706517%
# frame=  300 fps=299 q=-1.0 Lsize=     744KiB time=00:00:09.94 bitrate= 613.3kbits/s speed= 9.9x
# [libx264 @ 0x155ea16c0] frame I:3     Avg QP:26.02  size:  4521
# [libx264 @ 0x155ea16c0] frame P:111   Avg QP:27.63  size:  2581
# [libx264 @ 0x155ea16c0] frame B:186   Avg QP:29.87  size:  1240
# [libx264 @ 0x155ea16c0] consecutive B-frames: 12.3% 10.0% 15.0% 62.7%
# [libx264 @ 0x155ea16c0] mb I  I16..4:  2.5% 33.6% 63.9%
# [libx264 @ 0x155ea16c0] mb P  I16..4:  4.7% 23.8% 15.5%  P16..4: 22.8% 16.0% 10.5%  0.0%  0.0%    skip: 6.8%
# [libx264 @ 0x155ea16c0] mb B  I16..4:  1.6%  4.4%  1.2%  B16..8: 32.4% 20.3%  4.7%  direct: 6.9%  skip:28.5%  L0:44.9% L1:40.9% BI:14.2%
# [libx264 @ 0x155ea16c0] 8x8 transform intra:54.5% inter:18.1%
# [libx264 @ 0x155ea16c0] coded y,uvDC,uvAC intra: 72.0% 66.6% 30.9% inter: 22.3% 17.4% 1.1%
# [libx264 @ 0x155ea16c0] i16 v,h,dc,p: 40% 32% 19%  9%
# [libx264 @ 0x155ea16c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 30% 16%  2%  5%  5%  4%  6%  6%
# [libx264 @ 0x155ea16c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 26% 15%  3%  7%  6%  6%  5%  6%
# [libx264 @ 0x155ea16c0] i8c dc,h,v,p: 47% 22% 22%  8%
# [libx264 @ 0x155ea16c0] Weighted P-Frames: Y:5.4% UV:2.7%
# [libx264 @ 0x155ea16c0] kb/s:424.11
# ▶️ 1f9IgOjZjn4 @ 107s → +10s …
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with clang version 17.0.6
#   configuration: --prefix=/opt/anaconda3/envs/dataloader --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1728332276747/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1728332276747/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr1---sn-nfpuji-1gil.googlevideo.com/videoplayback?expire=1745868026&ei=moAPaNTwJYiF6dsP-5HCwQc&ip=2001%3A620%3A618%3A5c0%3A2%3A80b3%3A0%3A3d3&id=o-ALyXu5rSxBHGlPrj4BFn0r7YgKVyaOeZJJFE3Cuxc_C9&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1745846426%2C&mh=bN&mm=31%2C29&mn=sn-nfpuji-1gil%2Csn-1gi7znek&ms=au%2Crdu&mv=m&mvi=1&pcm2cms=yes&pl=32&rms=au%2Cau&gcr=ch&initcwndbps=4433750&bui=AecWEAYONl_esC9xaZQNFcAy5-8aGJTKn9CJS8V4Hq97LSQObu-YLy1lUr979fVMkdu209m1g4TwTBoP&vprv=1&svpuc=1&mime=video%2Fmp4&ns=uwHLEKGFsX5rg7N02gtH2LsQ&rqh=1&cnr=14&ratebypass=yes&dur=235.566&lmt=1710277357439242&mt=1745845981&fvip=2&lmw=1&c=TVHTML5&sefc=1&txp=4438434&n=W9oZJQCiyLiReg&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cgcr%2Cbui%2Cvprv%2Csvpuc%2Cmime%2Cns%2Crqh%2Ccnr%2Cratebypass%2Cdur%2Clmt&lsparams=met%2Cmh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Crms%2Cinitcwndbps&lsig=ACuhMU0wRAIgAistP0kBadAGn-o9MGGdSR5ev1QsVoKRz5yk5eZJ3ugCIG_XdE-Ykcyi7acbfcXi8-3BSwou3IbGkkO2q-jqWB2X&sig=AJfQdSswRQIhAPZKvzdi9Z2n6diREQEGVzxOXZmekkdTTW_24ce66CewAiBX5HqI-TRIkUvRRAX9mIBt_mmV_pJGTvkAeu2rfmVrvQ%3D%3D':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2024-03-12T20:32:19.000000Z
#   Duration: 00:03:55.52, start: 0.000000, bitrate: 582 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 480x360 [SAR 1:1 DAR 4:3], 450 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#       Metadata:
#         creation_time   : 2024-03-12T20:32:19.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 03/12/2024.
#         vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#       Metadata:
#         creation_time   : 2024-03-12T20:32:19.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 03/12/2024.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x115605910] using SAR=1/1
# [libx264 @ 0x115605910] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x115605910] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x115605910] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=1 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=2 psy=1 psy_rd=1.00:0.00 mixed_ref=0 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=0 threads=8 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=10 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'data_set_try1/videos/1f9IgOjZjn4_107s_256crop.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf61.7.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 256x256 [SAR 1:1 DAR 1:1], q=2-31, 29.97 fps, 30k tbn (default)
#       Metadata:
#         creation_time   : 2024-03-12T20:32:19.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 03/12/2024.
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#       Metadata:
#         creation_time   : 2024-03-12T20:32:19.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 03/12/2024.
#         vendor_id       : [0][0][0][0]
# [out#0/mp4 @ 0x115604a70] video:477KiB audio:249KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.788621%
# frame=  300 fps=0.0 q=-1.0 Lsize=     739KiB time=00:00:09.94 bitrate= 609.2kbits/s speed=23.9x
# [libx264 @ 0x115605910] frame I:8     Avg QP:24.45  size:  4800
# [libx264 @ 0x115605910] frame P:102   Avg QP:27.12  size:  2547
# [libx264 @ 0x115605910] frame B:190   Avg QP:29.29  size:   999
# [libx264 @ 0x115605910] consecutive B-frames:  8.3% 17.3% 13.0% 61.3%
# [libx264 @ 0x115605910] mb I  I16..4:  8.9% 29.5% 61.6%
# [libx264 @ 0x115605910] mb P  I16..4:  6.8% 24.3% 14.0%  P16..4: 17.7% 14.4% 10.1%  0.0%  0.0%    skip:12.7%
# [libx264 @ 0x115605910] mb B  I16..4:  1.5%  3.8%  1.2%  B16..8: 23.6% 15.8%  3.4%  direct: 5.8%  skip:45.0%  L0:42.5% L1:40.5% BI:16.9%
# [libx264 @ 0x115605910] 8x8 transform intra:51.7% inter:18.2%
# [libx264 @ 0x115605910] coded y,uvDC,uvAC intra: 68.6% 78.0% 29.2% inter: 18.9% 16.9% 0.2%
# [libx264 @ 0x115605910] i16 v,h,dc,p: 52% 17% 16% 14%
# [libx264 @ 0x115605910] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 29% 18% 17%  3%  6%  6%  5%  9%  7%
# [libx264 @ 0x115605910] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 20% 17%  3%  8%  6%  6%  6%  6%
# [libx264 @ 0x115605910] i8c dc,h,v,p: 40% 16% 28% 15%
# [libx264 @ 0x115605910] Weighted P-Frames: Y:2.0% UV:2.0%
# [libx264 @ 0x115605910] kb/s:390.01
# ▶️ r3VPp4TGkGQ @ 147s → +10s …
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with clang version 17.0.6
#   configuration: --prefix=/opt/anaconda3/envs/dataloader --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1728332276747/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1728332276747/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr3---sn-nfpuji-1gil.googlevideo.com/videoplayback?expire=1745868029&ei=nYAPaPL8KrWL6dsP2rnomQ4&ip=2001%3A620%3A618%3A5c0%3A2%3A80b3%3A0%3A3d3&id=o-AHiFh_aigm2AuvscS1ZCqJgLxqFsKssxxYXT-Z39sg_E&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1745846429%2C&mh=LF&mm=31%2C29&mn=sn-nfpuji-1gil%2Csn-1gi7znek&ms=au%2Crdu&mv=m&mvi=3&pcm2cms=yes&pl=32&rms=au%2Cau&initcwndbps=4433750&bui=AecWEAZPMamLl-AEto79Qq1vPYS3LGR6vCO-9LPF4kbUKEXJe_K-73hpgPSJ-6YKZpmaB9agBwCUMstu&vprv=1&svpuc=1&mime=video%2Fmp4&ns=32yMeOIutEH4fdt-cso7XzUQ&rqh=1&cnr=14&ratebypass=yes&dur=319.344&lmt=1665387543551677&mt=1745845981&fvip=1&lmw=1&c=TVHTML5&sefc=1&txp=5438434&n=YerOm8wya9-FQw&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cbui%2Cvprv%2Csvpuc%2Cmime%2Cns%2Crqh%2Ccnr%2Cratebypass%2Cdur%2Clmt&sig=AJfQdSswRgIhAOMRuBpMOiEC-kPR8-5xQcLUiDC30FPLZImjNcTUK1mAAiEA-RrdSvPFzTTHYH0FkDgfk0iLyOAYCuMYN5ZucQOgeNo%3D&lsparams=met%2Cmh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Crms%2Cinitcwndbps&lsig=ACuhMU0wRQIgAhy96j2Co7zcMhpMZMC_PG2vB2UQtS_k-r8K4vRDZCoCIQCuP7z2s1JPrWUM8j8YAyfAJn1rz6Y9tZFAS1yGML1b1w%3D%3D':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-05-12T14:49:32.000000Z
#   Duration: 00:05:19.30, start: 0.000000, bitrate: 718 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360 [SAR 1:1 DAR 16:9], 586 kb/s, 25 fps, 25 tbr, 12800 tbn (default)
#       Metadata:
#         creation_time   : 2019-05-12T14:49:32.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 05/12/2019.
#         vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#       Metadata:
#         creation_time   : 2019-05-12T14:49:32.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 05/12/2019.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x13cc74570] using SAR=1/1
# [libx264 @ 0x13cc74570] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x13cc74570] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x13cc74570] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=1 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=2 psy=1 psy_rd=1.00:0.00 mixed_ref=0 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=0 threads=8 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=10 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'data_set_try1/videos/r3VPp4TGkGQ_147s_256crop.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf61.7.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 256x256 [SAR 1:1 DAR 1:1], q=2-31, 25 fps, 12800 tbn (default)
#       Metadata:
#         creation_time   : 2019-05-12T14:49:32.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 05/12/2019.
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#       Metadata:
#         creation_time   : 2019-05-12T14:49:32.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 05/12/2019.
#         vendor_id       : [0][0][0][0]
# [out#0/mp4 @ 0x13cc758a0] video:456KiB audio:204KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.261570%
# frame=  250 fps=0.0 q=-1.0 Lsize=     668KiB time=00:00:09.92 bitrate= 552.0kbits/s speed=12.6x
# [libx264 @ 0x13cc74570] frame I:1     Avg QP:26.64  size:  2072
# [libx264 @ 0x13cc74570] frame P:248   Avg QP:26.44  size:  1862
# [libx264 @ 0x13cc74570] frame B:1     Avg QP:26.83  size:  2081
# [libx264 @ 0x13cc74570] consecutive B-frames: 99.2%  0.8%  0.0%  0.0%
# [libx264 @ 0x13cc74570] mb I  I16..4:  9.0% 75.8% 15.2%
# [libx264 @ 0x13cc74570] mb P  I16..4: 12.3% 70.8%  8.7%  P16..4:  4.0%  2.4%  0.8%  0.0%  0.0%    skip: 1.1%
# [libx264 @ 0x13cc74570] mb B  I16..4:  9.8% 68.4%  9.0%  B16..8:  4.3%  5.5%  0.4%  direct: 1.6%  skip: 1.2%  L0:18.3% L1:76.0% BI: 5.8%
# [libx264 @ 0x13cc74570] 8x8 transform intra:77.1% inter:37.7%
# [libx264 @ 0x13cc74570] coded y,uvDC,uvAC intra: 62.9% 59.3% 17.6% inter: 28.2% 42.1% 1.6%
# [libx264 @ 0x13cc74570] i16 v,h,dc,p: 35% 14% 15% 36%
# [libx264 @ 0x13cc74570] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 23% 18%  4%  7%  5%  5%  6%  7%
# [libx264 @ 0x13cc74570] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 24% 19%  4%  7%  4%  5%  4%  5%
# [libx264 @ 0x13cc74570] i8c dc,h,v,p: 48% 20% 23%  8%
# [libx264 @ 0x13cc74570] Weighted P-Frames: Y:14.9% UV:14.1%
# [libx264 @ 0x13cc74570] kb/s:372.76
# ▶️ xkjOXJDOOFo @ 162s → +10s …
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with clang version 17.0.6
#   configuration: --prefix=/opt/anaconda3/envs/dataloader --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1728332276747/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1728332276747/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr2---sn-nfpuji-1gil.googlevideo.com/videoplayback?expire=1745868033&ei=oYAPaM_eG9aG6dsP-c_o4Ak&ip=2001%3A620%3A618%3A5c0%3A2%3A80b3%3A0%3A3d3&id=o-AIRYktzyFKLtM1X7ouHwxYcFvQZ9FXAey6ImZlix9PWj&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1745846433%2C&mh=Kv&mm=31%2C29&mn=sn-nfpuji-1gil%2Csn-1gi7znes&ms=au%2Crdu&mv=m&mvi=2&pcm2cms=yes&pl=32&rms=au%2Cau&initcwndbps=4433750&bui=AecWEAYFZkg-FyLB6FYgdjfLDBhW6pk9dSXEU_T5Fz46MV1SpMUbyctTQqXz_bXXpzMW002WJH5WgsZD&vprv=1&svpuc=1&mime=video%2Fmp4&ns=iTU00KHkI6MVNFWZni0wwyAQ&rqh=1&cnr=14&ratebypass=yes&dur=221.402&lmt=1709312178394543&mt=1745845981&fvip=4&lmw=1&c=TVHTML5&sefc=1&txp=4538434&n=rBK--BXGD43lqw&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cbui%2Cvprv%2Csvpuc%2Cmime%2Cns%2Crqh%2Ccnr%2Cratebypass%2Cdur%2Clmt&sig=AJfQdSswRQIgNMEnHqoDgs_kEPHxb44QVl6Grk7lZ0CWBTAx3MpY7_oCIQC68NAJa2u34Y0okyKfREeyJdD0YC6hgF0yH42sGGi41Q%3D%3D&lsparams=met%2Cmh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Crms%2Cinitcwndbps&lsig=ACuhMU0wRAIgKA13_l1pfZr43tc5YGnqPDuiv6A1o8vWP8T1v8H9J4ACIA_JlnaTmmNyhdZdHFJINAogrRarZI7A7CcJH27mHrDW':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2024-03-01T16:08:17.000000Z
#   Duration: 00:03:41.36, start: 0.000000, bitrate: 339 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360 [SAR 1:1 DAR 16:9], 208 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#       Metadata:
#         creation_time   : 2024-03-01T16:08:17.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 03/01/2024.
#         vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#       Metadata:
#         creation_time   : 2024-03-01T16:08:17.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 03/01/2024.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x121694a40] using SAR=1/1
# [libx264 @ 0x121694a40] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x121694a40] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x121694a40] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=1 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=2 psy=1 psy_rd=1.00:0.00 mixed_ref=0 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=0 threads=8 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=23 scenecut=40 intra_refresh=0 rc_lookahead=10 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'data_set_try1/videos/xkjOXJDOOFo_162s_256crop.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf61.7.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 256x256 [SAR 1:1 DAR 1:1], q=2-31, 23.98 fps, 24k tbn (default)
#       Metadata:
#         creation_time   : 2024-03-01T16:08:17.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 03/01/2024.
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#       Metadata:
#         creation_time   : 2024-03-01T16:08:17.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 03/01/2024.
#         vendor_id       : [0][0][0][0]
# [out#0/mp4 @ 0x121684e20] video:170KiB audio:216KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 2.483828%
# frame=  239 fps=0.0 q=-1.0 Lsize=     396KiB time=00:00:09.92 bitrate= 326.6kbits/s speed=35.1x
# [libx264 @ 0x121694a40] frame I:1     Avg QP:23.99  size:  3978
# [libx264 @ 0x121694a40] frame P:97    Avg QP:24.86  size:  1291
# [libx264 @ 0x121694a40] frame B:141   Avg QP:28.89  size:   316
# [libx264 @ 0x121694a40] consecutive B-frames:  1.7% 54.4% 13.8% 30.1%
# [libx264 @ 0x121694a40] mb I  I16..4:  5.1% 45.7% 49.2%
# [libx264 @ 0x121694a40] mb P  I16..4:  1.1%  8.6%  2.5%  P16..4: 29.0% 20.0% 12.1%  0.0%  0.0%    skip:26.7%
# [libx264 @ 0x121694a40] mb B  I16..4:  0.2%  1.5%  0.2%  B16..8: 14.5%  6.5%  0.9%  direct: 3.0%  skip:73.3%  L0:34.8% L1:51.1% BI:14.1%
# [libx264 @ 0x121694a40] 8x8 transform intra:70.0% inter:22.8%
# [libx264 @ 0x121694a40] coded y,uvDC,uvAC intra: 76.2% 58.5% 12.9% inter: 10.2% 5.4% 0.2%
# [libx264 @ 0x121694a40] i16 v,h,dc,p: 22% 23% 11% 44%
# [libx264 @ 0x121694a40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 26% 14%  4%  7%  7%  6%  7%  8%
# [libx264 @ 0x121694a40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 23% 18%  4%  9%  7%  6%  5%  6%
# [libx264 @ 0x121694a40] i8c dc,h,v,p: 50% 21% 22%  8%
# [libx264 @ 0x121694a40] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x121694a40] kb/s:139.48
# ▶️ OVBQuUJhtfg @ 30s → +10s …
# ERROR: [youtube] OVBQuUJhtfg: Video unavailable
# ⚠️ Erreur pour OVBQuUJhtfg@30s : ERROR: [youtube] OVBQuUJhtfg: Video unavailable
# ▶️ CeTbzVsGfRw @ 30s → +10s …
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with clang version 17.0.6
#   configuration: --prefix=/opt/anaconda3/envs/dataloader --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1728332276747/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1728332276747/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# ✅ Tous les segments (10 s) sont prêts en MP4 dans data_set_try1/videos
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr1---sn-nfpuji-1gil.googlevideo.com/videoplayback?expire=1745868036&ei=pIAPaOKKNtPO6dsPo9K1-Ao&ip=2001%3A620%3A618%3A5c0%3A2%3A80b3%3A0%3A3d3&id=o-APCUFwqp9pU4uDV38v71gcyMIIA9sq-Ak9fj-5Z48BUL&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1745846436%2C&mh=tr&mm=31%2C29&mn=sn-nfpuji-1gil%2Csn-1giz7n7l&ms=au%2Crdu&mv=m&mvi=1&pcm2cms=yes&pl=32&rms=au%2Cau&initcwndbps=4433750&bui=AecWEAZs0OQHeW5kiPBvg0AkjuSh2GqGLpensPdvFK-p2KElCiGx7GHfWIjNCUNuYwrQf3D5po71OEUW&vprv=1&svpuc=1&mime=video%2Fmp4&ns=P09nQk3pyhDt3yzwyLO31wcQ&rqh=1&cnr=14&ratebypass=yes&dur=46.068&lmt=1744555934425586&mt=1745845981&fvip=2&lmw=1&c=TVHTML5&sefc=1&txp=8208224&n=YRUKGLJNS9-RcQ&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cbui%2Cvprv%2Csvpuc%2Cmime%2Cns%2Crqh%2Ccnr%2Cratebypass%2Cdur%2Clmt&sig=AJfQdSswRQIhAPSalUoWYRTiKtM9SpYJ1PJtAM83ui2VxL44xHs2f2pkAiB7yfcxBd1ToIIJQxXq8fizk6MbkS7A2zaelC6ad-9y5A%3D%3D&lsparams=met%2Cmh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Crms%2Cinitcwndbps&lsig=ACuhMU0wRAIgCZf0Bj-Z_3szc_H1tvHhOsMRCvDzHL8JWzRToa801IICIDghYXCjxtsn5Hki6AdSr2Kp-B3afiSM9cZ-BNHE6mDV':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2024-04-30T16:20:39.000000Z
#     encoder         : Google
#   Duration: 00:00:46.02, start: 0.000000, bitrate: 609 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360 [SAR 1:1 DAR 16:9], 477 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#       Metadata:
#         creation_time   : 2024-04-30T16:20:39.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 04/30/2024.
#         vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#       Metadata:
#         creation_time   : 2024-04-30T16:20:39.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 04/30/2024.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x12be350c0] using SAR=1/1
# [libx264 @ 0x12be350c0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12be350c0] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x12be350c0] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=1 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=2 psy=1 psy_rd=1.00:0.00 mixed_ref=0 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=0 threads=8 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=10 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'data_set_try1/videos/CeTbzVsGfRw_30s_256crop.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf61.7.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 256x256 [SAR 1:1 DAR 1:1], q=2-31, 29.97 fps, 30k tbn (default)
#       Metadata:
#         creation_time   : 2024-04-30T16:20:39.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 04/30/2024.
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#       Metadata:
#         creation_time   : 2024-04-30T16:20:39.000000Z
#         handler_name    : ISO Media file produced by Google Inc. Created on: 04/30/2024.
#         vendor_id       : [0][0][0][0]
# [out#0/mp4 @ 0x12be34280] video:205KiB audio:209KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 3.047415%
# frame=  299 fps=0.0 q=-1.0 Lsize=     426KiB time=00:00:09.94 bitrate= 351.3kbits/s speed=51.7x
# [libx264 @ 0x12be350c0] frame I:2     Avg QP:23.00  size:  4098
# [libx264 @ 0x12be350c0] frame P:81    Avg QP:25.32  size:  1688
# [libx264 @ 0x12be350c0] frame B:216   Avg QP:28.89  size:   299
# [libx264 @ 0x12be350c0] consecutive B-frames:  1.0%  4.7% 10.0% 84.3%
# [libx264 @ 0x12be350c0] mb I  I16..4: 10.2% 52.1% 37.7%
# [libx264 @ 0x12be350c0] mb P  I16..4:  6.2% 15.7%  1.1%  P16..4: 32.7% 21.9% 14.5%  0.0%  0.0%    skip: 8.1%
# [libx264 @ 0x12be350c0] mb B  I16..4:  0.7%  0.5%  0.0%  B16..8: 22.4%  6.7%  0.4%  direct: 4.4%  skip:64.9%  L0:32.7% L1:44.7% BI:22.6%
# [libx264 @ 0x12be350c0] 8x8 transform intra:64.3% inter:27.4%
# [libx264 @ 0x12be350c0] coded y,uvDC,uvAC intra: 50.0% 43.0% 3.3% inter: 9.8% 6.6% 0.0%
# [libx264 @ 0x12be350c0] i16 v,h,dc,p: 44% 20% 17% 20%
# [libx264 @ 0x12be350c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 22% 23%  2%  5%  5%  4%  4%  4%
# [libx264 @ 0x12be350c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 47% 12% 13%  3%  7%  6%  4%  5%  4%
# [libx264 @ 0x12be350c0] i8c dc,h,v,p: 54% 13% 28%  6%
# [libx264 @ 0x12be350c0] Weighted P-Frames: Y:35.8% UV:17.3%
# [libx264 @ 0x12be350c0] kb/s:167.96

# %% [markdown]
# # THIS PART TRY TO CREATE THE DATASET ON THE FLY WHILE DOWNLOADING THE VIDEO

# %%
import os, shutil, subprocess, time, sys
import pandas as pd
import numpy as np
from pydub import AudioSegment
from yt_dlp import YoutubeDL
import cv2

OUTPUT_DIR   = "data_set_try1/processed"       # dossier racine de sortie
CSV_LABELS   = "data_set_try1/dataset/labels_semantic_clusters.csv"
CSV_DATA     = "data_set_try1/dataset/vggsound.csv"
CLUSTER      = '3'
DURATION_SEC = 10

# check ffmpeg
if shutil.which("ffmpeg") is None:
    raise RuntimeError("⚠️ ffmpeg n'est pas installé — indispensable.")
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
# Cell 2 — Fonctions utilitaires

def sec_to_timestamp(s: int) -> str:
    return time.strftime("%H:%M:%S", time.gmtime(s))

def download_segment(video_id: str, start: int, dur: int, out_dir: str) -> str:
    """Récupère le segment mp4 (audio+vidéo) et renvoie le chemin."""
    url = f"https://www.youtube.com/watch?v={video_id}"
    ydl_opts = {'format': 'best[height<=360][ext=mp4]', 'quiet': True, 'skip_download': True}
    with YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(url, download=False)
        stream_url = info['url']
    t0 = sec_to_timestamp(start)
    segment_path = os.path.join(out_dir, "segment.mp4")
    cmd = [
        'ffmpeg', '-ss', t0, '-i', stream_url,
        '-t', str(dur), '-c', 'copy',
        segment_path
    ]
    subprocess.run(cmd, check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    return segment_path

def download_segment_crop256(video_id: str, start_sec: int, duration: int, dest_folder: str) -> str:
    """
    1) Récupère l’URL du flux MP4 (360p).
    2) Seek + coupe la portion [start_sec, start_sec+duration] via ffmpeg -ss/-t.
    3) Applique un crop 256×256 centré.
    4) Ré-encode la vidéo en H.264 (libx264) et copie l'audio AAC.
    Retourne le chemin du fichier généré.
    """
    os.makedirs(dest_folder, exist_ok=True)
    url = f"https://www.youtube.com/watch?v={video_id}"

    # 1) Récupère l'URL directe du flux MP4
    ydl_opts = {
        'format': 'best[height<=360][ext=mp4]',
        'quiet': True,
        'skip_download': True,
    }
    with YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(url, download=False)
        stream_url = info['url']

    # 2) Prépare timestamps et nom de sortie
    t0         = sec_to_timestamp(start_sec)
    out_name   = "segment.mp4"
    out_path   = os.path.join(dest_folder, out_name)

    # 3) ffmpeg : seek rapide (-ss avant -i), durée (-t), crop, encode video, copy audio
    cmd = [
        'ffmpeg',
        '-ss', t0,
        '-i', stream_url,
        '-t', str(duration),
        '-vf', 'crop=256:256:(in_w-256)/2:(in_h-256)/2',
        '-c:v', 'libx264',    # encode video H264
        '-preset', 'veryfast',
        '-crf', '23',
        '-c:a', 'copy',       # copie l'audio tel quel
        out_path
    ]
    subprocess.run(cmd, check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    return out_path


def analyze_audio_max_timestamp(video_path: str) -> float:
    """Retourne en secondes le point de volume max dans segment.mp4."""
    audio = AudioSegment.from_file(video_path)
    mono  = audio.set_channels(1)
    arr   = np.array(mono.get_array_of_samples())
    idx   = int(np.argmax(np.abs(arr)))
    return idx / mono.frame_rate

def extract_best_thumbnail(video_path: str, ts: float, out_path: str):
    """
    => Prend plusieurs frames autour de ts (±0.5s), calcule la variance
       du Laplacien (proxy pour la netteté), choisit la meilleure,
       fait une égalisation d’histogramme sur la luminance, et sauve.
    """
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise RuntimeError(f"Impossible d'ouvrir {video_path}")
    fps      = cap.get(cv2.CAP_PROP_FPS) or 25
    frame_ct = cap.get(cv2.CAP_PROP_FRAME_COUNT)
    duration = frame_ct / fps

    # offsets en secondes autour du pic
    offsets = [-0.5, -0.25, 0, 0.25, 0.5]
    best_score = -1
    best_frame = None

    for off in offsets:
        t = min(max(ts + off, 0), duration)
        cap.set(cv2.CAP_PROP_POS_MSEC, t * 1000)
        ret, frame = cap.read()
        if not ret: 
            continue
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        score = cv2.Laplacian(gray, cv2.CV_64F).var()
        if score > best_score:
            best_score, best_frame = score, frame

    cap.release()

    if best_frame is None:
        raise RuntimeError("Aucune frame extraite pour la thumbnail")

    # égalisation de l'histogramme sur le canal Y de YUV
    yuv = cv2.cvtColor(best_frame, cv2.COLOR_BGR2YUV)
    yuv[:,:,0] = cv2.equalizeHist(yuv[:,:,0])
    enhanced = cv2.cvtColor(yuv, cv2.COLOR_YUV2BGR)

    cv2.imwrite(out_path, enhanced)

def strip_audio(video_path: str, out_path: str):
    """Génère video_no_audio.mp4."""
    cmd = ['ffmpeg', '-i', video_path, '-c', 'copy', '-an', out_path]
    subprocess.run(cmd, check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

def extract_audio(video_path: str, out_path: str):
    """Génère audio.m4a."""
    cmd = ['ffmpeg', '-i', video_path, '-vn', '-c:a', 'copy', out_path]
    subprocess.run(cmd, check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

def process_one(vid: str, start: int):
    """Orchestre tout pour un segment."""
    name = f"{vid}_{start}s"
    folder = os.path.join(OUTPUT_DIR, name)
    os.makedirs(folder, exist_ok=True)

    seg = download_segment_crop256(vid, start, DURATION_SEC, folder)
    ts  = analyze_audio_max_timestamp(seg)
    extract_best_thumbnail(seg, ts, os.path.join(folder, "thumbnail.jpg"))
    strip_audio(seg,  os.path.join(folder, "video_no_audio.mp4"))
    extract_audio(seg, os.path.join(folder, "audio.m4a"))

# %%
# # Cell 3 — Lecture & filtrage
# labels_df = pd.read_csv(CSV_LABELS, header=0)

# used_labels = labels_df[labels_df['cluster']==CLUSTER]['label'].values

# data_df = pd.read_csv(CSV_DATA, header=None,
#                       names=['video_id','start_sec','label','split'])
# sub_df = data_df[data_df['label'].isin(used_labels)].sample(10, random_state=0)


# Cell 3 — Lecture & filtrage du dataset
labels_df = pd.read_csv(CSV_LABELS, header=None,
                        names=['label','count','cluster'])
used_labels = labels_df[labels_df['cluster']==CLUSTER]['label'].values

data_df = pd.read_csv(CSV_DATA, header=None,
                      names=['video_id','start_sec','label','split'])
sub_df = data_df[data_df['label'].isin(used_labels)].sample(10, random_state=42)

# %%
# Cell 4 — Traitement en boucle
for vid, start, *_ in sub_df.itertuples(index=False):
    print(f"🔄 Processing {vid} @ {start}s …")
    try:
        process_one(vid, int(start))
    except Exception as e:
        print(f"⚠️ Erreur pour {vid}@{start}s : {e}")

print("✅ Tout est prêt dans", OUTPUT_DIR)
# Out:
# 🔄 Processing 5PVKgUGg0LQ @ 450s …
# ⚠️ Erreur pour 5PVKgUGg0LQ@450s : Command '['ffmpeg', '-ss', '00:07:30', '-i', 'https://rr1---sn-nfpuji-1gil.googlevideo.com/videoplayback?expire=1745875939&ei=g58PaLHDAZyG6dsPw7jdwQQ&ip=2001%3A620%3A618%3A5c0%3A2%3A80b3%3A0%3A3d3&id=o-AMjaVa6-inKhhYWi_lNVAg6DeOIB60pYvmJrNCH0rkv_&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1745854339%2C&mh=7z&mm=31%2C29&mn=sn-nfpuji-1gil%2Csn-1gi7znek&ms=au%2Crdu&mv=m&mvi=1&pcm2cms=yes&pl=32&rms=au%2Cau&initcwndbps=4430000&bui=AecWEAblI85kL2Z0_jyeYOf2TIdUXhKE_di8pUwTuhgSWEOIgmfMyPmbnfPZjbzv32Zw4dGP8T5yf3D1&vprv=1&svpuc=1&mime=video%2Fmp4&ns=o727fY8-EboKZzse56YIvHkQ&rqh=1&cnr=14&ratebypass=yes&dur=664.926&lmt=1743737791279412&mt=1745853906&fvip=1&lmw=1&c=TVHTML5&sefc=1&txp=5438534&n=SL5K9tWimzub4Q&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cbui%2Cvprv%2Csvpuc%2Cmime%2Cns%2Crqh%2Ccnr%2Cratebypass%2Cdur%2Clmt&sig=AJfQdSswRQIgBwdo-51gClj4RKA3xgSgdJQUYl2O7SjGgAwQFRJM_5YCIQCXtgk0KsgRIjeAss3AHmVnrZpktW3jG-C-tgtEkRnlOw%3D%3D&lsparams=met%2Cmh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Crms%2Cinitcwndbps&lsig=ACuhMU0wRAIgL0Wy76_IT-TemqN-MrS2gSZvJsbzU7ZoecBIU3drHOQCIFQ1w2xySwOTdGGbkUwJXWL7HosHMvciYZ7tLtHcPh9t', '-t', '10', '-vf', 'crop=256:256:(in_w-256)/2:(in_h-256)/2', '-c:v', 'libx264', '-preset', 'veryfast', '-crf', '23', '-c:a', 'copy', 'data_set_try1/processed/5PVKgUGg0LQ_450s/segment.mp4']' returned non-zero exit status 8.
# 🔄 Processing wd2RVda164o @ 30s …
# ⚠️ Erreur pour wd2RVda164o@30s : Command '['ffmpeg', '-ss', '00:00:30', '-i', 'https://rr3---sn-nfpuji-1gil.googlevideo.com/videoplayback?expire=1745875942&ei=hp8PaNmVKNHV6dsPrJyY2QE&ip=2001%3A620%3A618%3A5c0%3A2%3A80b3%3A0%3A3d3&id=o-ADKujC2GueQmARJ_uDQZ9DvR0GLIRx0fm5X8NWpJE6Lk&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1745854342%2C&mh=gA&mm=31%2C29&mn=sn-nfpuji-1gil%2Csn-1giz7n7l&ms=au%2Crdu&mv=m&mvi=3&pcm2cms=yes&pl=32&rms=au%2Cau&initcwndbps=4430000&bui=AecWEAZsM5lvYYLh8s5-S79EqpTgsI-Az-QUtAwQM0t7w1YL6yMOn30sjt-xnFUWPQSVW7rmlPkufL3F&vprv=1&svpuc=1&mime=video%2Fmp4&ns=mlP8bhRKu2o_XtF1gvO-ljMQ&rqh=1&cnr=14&ratebypass=yes&dur=374.166&lmt=1661826025439816&mt=1745853906&fvip=1&lmw=1&c=TVHTML5&sefc=1&txp=1318224&n=5uC5R5dby5JCVw&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cbui%2Cvprv%2Csvpuc%2Cmime%2Cns%2Crqh%2Ccnr%2Cratebypass%2Cdur%2Clmt&sig=AJfQdSswRQIhANqAWATUGL7E20l43DmORxEUoZ2NJTbrNSHUhkuasBl_AiBb-Sc1w5BnfGCloE39sPX6jfvQbMocwKDGUye_IY1bAg%3D%3D&lsparams=met%2Cmh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Crms%2Cinitcwndbps&lsig=ACuhMU0wRAIgI4zUhagbhyMPFwkdRiwqE2X5czpiKZbmfV6ny1klkJ4CIFQA9dVeAR9mHbbA8EKhbHigSWmzsSJufKI9Ni3NNlSy', '-t', '10', '-vf', 'crop=256:256:(in_w-256)/2:(in_h-256)/2', '-c:v', 'libx264', '-preset', 'veryfast', '-crf', '23', '-c:a', 'copy', 'data_set_try1/processed/wd2RVda164o_30s/segment.mp4']' returned non-zero exit status 8.
# 🔄 Processing IpHCwR7ACjI @ 189s …
# ⚠️ Erreur pour IpHCwR7ACjI@189s : Command '['ffmpeg', '-ss', '00:03:09', '-i', 'https://rr2---sn-nfpuji-1gil.googlevideo.com/videoplayback?expire=1745875944&ei=iJ8PaKa6K8_F6dsPkrTrsQE&ip=2001%3A620%3A618%3A5c0%3A2%3A80b3%3A0%3A3d3&id=o-AGz1o3X87JDhAXn1DlbRFvLPDknPwH5l5objkjq3asu0&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1745854344%2C&mh=rB&mm=31%2C29&mn=sn-nfpuji-1gil%2Csn-1gi7znek&ms=au%2Crdu&mv=m&mvi=2&pcm2cms=yes&pl=32&rms=au%2Cau&initcwndbps=4430000&bui=AecWEAaYBDhpfINzx6Mz3Fvw77HsZn3eJFdLTytzj4RI-lQ38tytwDQdULVvHmuPCJ4Qpwz6wgb6M4Zu&vprv=1&svpuc=1&mime=video%2Fmp4&ns=F9viIYVtxJGn3opnorvZKu8Q&rqh=1&cnr=14&ratebypass=yes&dur=1041.600&lmt=1738736159285028&mt=1745853906&fvip=2&lmw=1&c=TVHTML5&sefc=1&txp=8208224&n=LoHzYRQdQyURNw&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cbui%2Cvprv%2Csvpuc%2Cmime%2Cns%2Crqh%2Ccnr%2Cratebypass%2Cdur%2Clmt&lsparams=met%2Cmh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Crms%2Cinitcwndbps&lsig=ACuhMU0wRAIgL4CE6KzQ5EFpwCqIx-shzPek6yc_-8WDnqAsizzCqfcCIGh94BzALDls6hLVv2Ygcc7EEmZwTVV7sJePFrL4UTgE&sig=AJfQdSswRAIgFhTqIVJVTb_0hf2pgLqtYMp6xTGKSI_7of771R5ayqECIDxgrE852c_W3dmNT67nVpmEEaXdQkF95pYwGzrN4y4g', '-t', '10', '-vf', 'crop=256:256:(in_w-256)/2:(in_h-256)/2', '-c:v', 'libx264', '-preset', 'veryfast', '-crf', '23', '-c:a', 'copy', 'data_set_try1/processed/IpHCwR7ACjI_189s/segment.mp4']' returned non-zero exit status 8.
# 🔄 Processing 9Qttcz2JRlI @ 282s …
# ⚠️ Erreur pour 9Qttcz2JRlI@282s : Command '['ffmpeg', '-ss', '00:04:42', '-i', 'https://rr3---sn-nfpuji-1gil.googlevideo.com/videoplayback?expire=1745875947&ei=i58PaPfwCf6I6dsPk-XYoA4&ip=2001%3A620%3A618%3A5c0%3A2%3A80b3%3A0%3A3d3&id=o-AMveLKWH_h3_ZgunnKnFgNQMixSRPbgQBfHL6PwSP-dF&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1745854347%2C&mh=q5&mm=31%2C29&mn=sn-nfpuji-1gil%2Csn-1gi7znek&ms=au%2Crdu&mv=m&mvi=3&pcm2cms=yes&pl=32&rms=au%2Cau&initcwndbps=4430000&bui=AecWEAZ0gMtogk6GqPsfBelGsFAGePXJYwGPc5Q3ShhCqfV6JZwAz7Xu_MqWbIkPqlin5rdaZRYo1H__&vprv=1&svpuc=1&mime=video%2Fmp4&ns=mPYxxGTXCkOh9hESey1GMtEQ&rqh=1&cnr=14&ratebypass=yes&dur=321.108&lmt=1706860381100955&mt=1745853906&fvip=1&lmw=1&c=TVHTML5&sefc=1&txp=2218224&n=lD4Of5Q9qGrF5w&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cbui%2Cvprv%2Csvpuc%2Cmime%2Cns%2Crqh%2Ccnr%2Cratebypass%2Cdur%2Clmt&sig=AJfQdSswRQIhAON_KZz5cB59QHU2slYASU7b1zzBTKxwuRryO0YIxCZDAiAvlrtu2Q_ECfUlig9vK4e3EtfYe6gsEEaTmzKgJozD0g%3D%3D&lsparams=met%2Cmh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Crms%2Cinitcwndbps&lsig=ACuhMU0wRQIhAII4VWWtkyg2XvAxZNFJKeEhZT65g2MXDD8dXUch22XwAiAF7azlELx31www8Vrd0lBqWwBozojK8nqMVKu5ck2jqA%3D%3D', '-t', '10', '-vf', 'crop=256:256:(in_w-256)/2:(in_h-256)/2', '-c:v', 'libx264', '-preset', 'veryfast', '-crf', '23', '-c:a', 'copy', 'data_set_try1/processed/9Qttcz2JRlI_282s/segment.mp4']' returned non-zero exit status 8.
# 🔄 Processing wwxXsszinio @ 105s …
# ⚠️ Erreur pour wwxXsszinio@105s : Command '['ffmpeg', '-ss', '00:01:45', '-i', 'https://rr1---sn-nfpuji-1gil.googlevideo.com/videoplayback?expire=1745875949&ei=jZ8PaL3HDvKN6dsPyLGX8Ao&ip=2001%3A620%3A618%3A5c0%3A2%3A80b3%3A0%3A3d3&id=o-AJHngE2KyqlCInwQAbPYExyAeYlAMhwKjiSil5iaQDfj&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1745854349%2C&mh=fh&mm=31%2C29&mn=sn-nfpuji-1gil%2Csn-1gi7znek&ms=au%2Crdu&mv=m&mvi=1&pcm2cms=yes&pl=32&rms=au%2Cau&initcwndbps=4430000&bui=AecWEAb-CfVohw4tSlO1DSU6rOEioH1iwFnq9fcBggdrfMUvL9rSDBAzXzz5w31B0CdZwm__1_ZMgwpU&vprv=1&svpuc=1&mime=video%2Fmp4&ns=DeVA6suaFpoV6s28GQyGOzcQ&rqh=1&cnr=14&ratebypass=yes&dur=155.202&lmt=1673894712059340&mt=1745853906&fvip=3&lmw=1&c=TVHTML5&sefc=1&txp=6219224&n=XKTHsm9jtUCsGQ&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cbui%2Cvprv%2Csvpuc%2Cmime%2Cns%2Crqh%2Ccnr%2Cratebypass%2Cdur%2Clmt&sig=AJfQdSswRgIhAMJFeX493V6dUwFM4hHHU-DpnUMLnbkG4ccMGtuZEGQfAiEA4iyfPAQUNjfBC2d9TvkfFctJsCsnvQaW7UZBohQS3HA%3D&lsparams=met%2Cmh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Crms%2Cinitcwndbps&lsig=ACuhMU0wRQIhAP8UE0grmYCQ0MxiVFl6FaHxUeaodn83DCnFQM1sOAAzAiBRQ7kWIjFP-hOJam4Qe9p8Br-WKH_d7hJGt1b-EiWM2w%3D%3D', '-t', '10', '-vf', 'crop=256:256:(in_w-256)/2:(in_h-256)/2', '-c:v', 'libx264', '-preset', 'veryfast', '-crf', '23', '-c:a', 'copy', 'data_set_try1/processed/wwxXsszinio_105s/segment.mp4']' returned non-zero exit status 8.
# 🔄 Processing 1f9IgOjZjn4 @ 107s …
# ⚠️ Erreur pour 1f9IgOjZjn4@107s : Command '['ffmpeg', '-ss', '00:01:47', '-i', 'https://rr1---sn-nfpuji-1gil.googlevideo.com/videoplayback?expire=1745875951&ei=j58PaOfNGeuM6dsP_Pfm0Q0&ip=2001%3A620%3A618%3A5c0%3A2%3A80b3%3A0%3A3d3&id=o-AI9njXpBf_7oJJcBKF32oE4qamTZFs1KBcU40furxo_Z&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1745854351%2C&mh=bN&mm=31%2C29&mn=sn-nfpuji-1gil%2Csn-1gi7znek&ms=au%2Crdu&mv=m&mvi=1&pcm2cms=yes&pl=32&rms=au%2Cau&gcr=ch&initcwndbps=4430000&bui=AecWEAatP1fpNK8z4YoVzrL1HvYW2pC1e955cZK4-xqGaLcmzx8wboFLEH7vlROz4fxksoIUlVoVadIU&vprv=1&svpuc=1&mime=video%2Fmp4&ns=GshndzFhRe-JexFvzBflIR4Q&rqh=1&cnr=14&ratebypass=yes&dur=235.566&lmt=1710277357439242&mt=1745853906&fvip=2&lmw=1&c=TVHTML5&sefc=1&txp=4438434&n=YJAsKOKspT2EPg&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cgcr%2Cbui%2Cvprv%2Csvpuc%2Cmime%2Cns%2Crqh%2Ccnr%2Cratebypass%2Cdur%2Clmt&lsparams=met%2Cmh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Crms%2Cinitcwndbps&lsig=ACuhMU0wRQIhAKyewPaV3V9uLFYcXK9Mfl8c7E-OWXJ3y_bZANGx-yh3AiAlrsfWMKp24sRT0dB_9tt6a0bwoXmABulq34wwsZPB8w%3D%3D&sig=AJfQdSswRQIhAMpidAl4AWnlcDu_fPpf-sHVXazgFiulPSGApYpayx9DAiBkEwGuqPzvfrkY0ZO8LcpJTV8IfPaTPqubtfMSq3fmsQ%3D%3D', '-t', '10', '-vf', 'crop=256:256:(in_w-256)/2:(in_h-256)/2', '-c:v', 'libx264', '-preset', 'veryfast', '-crf', '23', '-c:a', 'copy', 'data_set_try1/processed/1f9IgOjZjn4_107s/segment.mp4']' returned non-zero exit status 8.
# 🔄 Processing r3VPp4TGkGQ @ 147s …
# ⚠️ Erreur pour r3VPp4TGkGQ@147s : Command '['ffmpeg', '-ss', '00:02:27', '-i', 'https://rr3---sn-nfpuji-1gil.googlevideo.com/videoplayback?expire=1745875953&ei=kZ8PaMCwNu2izPsPuunR2Ag&ip=2001%3A620%3A618%3A5c0%3A2%3A80b3%3A0%3A3d3&id=o-ACzdWddYgnNIHALkU-r2tiMdZxoWkXIEuhG6GSLHPkhD&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1745854353%2C&mh=LF&mm=31%2C29&mn=sn-nfpuji-1gil%2Csn-1gi7znek&ms=au%2Crdu&mv=m&mvi=3&pcm2cms=yes&pl=32&rms=au%2Cau&initcwndbps=4430000&bui=AecWEAaReReFyyt5b0xMbioiil9dZBcHYHdoIYTDYekbtT_HVI9xzkPhnSex-8GbDeZD2VmtgXPAhZVo&vprv=1&svpuc=1&mime=video%2Fmp4&ns=0xPhQLxJI7I9bLeTEHRMb1sQ&rqh=1&cnr=14&ratebypass=yes&dur=319.344&lmt=1665387543551677&mt=1745853906&fvip=1&lmw=1&c=TVHTML5&sefc=1&txp=5438434&n=7drBYVh-5dK7YQ&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cbui%2Cvprv%2Csvpuc%2Cmime%2Cns%2Crqh%2Ccnr%2Cratebypass%2Cdur%2Clmt&sig=AJfQdSswRAIgd6goTQb9Y-kdnL2jLCu6qSO59f-B9vN1o5l3ntRUxk0CIHmwvFYpkv5ygtbzmcvDs2noiUTsoJ5EagNyHS8tXaYh&lsparams=met%2Cmh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Crms%2Cinitcwndbps&lsig=ACuhMU0wRQIhAKCIv2vJMN615ZBPxbbO-9HAdnG9ogs4Z57WpkCH_5zUAiAbzn9xasGKaXwYh_FIcR7g_ri2pq7Dvhmi7lEgWyUNNA%3D%3D', '-t', '10', '-vf', 'crop=256:256:(in_w-256)/2:(in_h-256)/2', '-c:v', 'libx264', '-preset', 'veryfast', '-crf', '23', '-c:a', 'copy', 'data_set_try1/processed/r3VPp4TGkGQ_147s/segment.mp4']' returned non-zero exit status 8.
# 🔄 Processing xkjOXJDOOFo @ 162s …
# ⚠️ Erreur pour xkjOXJDOOFo@162s : Command '['ffmpeg', '-ss', '00:02:42', '-i', 'https://rr2---sn-nfpuji-1gil.googlevideo.com/videoplayback?expire=1745875956&ei=lJ8PaLPmCpe06dsPx--NoQQ&ip=2001%3A620%3A618%3A5c0%3A2%3A80b3%3A0%3A3d3&id=o-ANM7XagLTIV2MgfpVogTvdIZ8AvnAV8J5v900Gr_tjC5&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1745854356%2C&mh=Kv&mm=31%2C29&mn=sn-nfpuji-1gil%2Csn-1gi7znes&ms=au%2Crdu&mv=m&mvi=2&pcm2cms=yes&pl=32&rms=au%2Cau&initcwndbps=4430000&bui=AecWEAaFHBJ8YLyPNh_02CQ99yYB0XzRcZuO_7IEn9fQZAJi_fHX5n6UUE_W49ESGlb3Hr1KLMZqIxBa&vprv=1&svpuc=1&mime=video%2Fmp4&ns=PAtu6izW-RYxKVEICRtb53YQ&rqh=1&cnr=14&ratebypass=yes&dur=221.402&lmt=1709312178394543&mt=1745853906&fvip=4&lmw=1&c=TVHTML5&sefc=1&txp=4538434&n=psJ9C2YUfcEFyQ&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cbui%2Cvprv%2Csvpuc%2Cmime%2Cns%2Crqh%2Ccnr%2Cratebypass%2Cdur%2Clmt&sig=AJfQdSswRQIhAJqxXoe8ndLUMozmKOxxmOFV3ktLN_I_Sk3R5gqhgnYiAiABXANOOTX-cG0wxJnmnJj6roxw4agltbVOKexcgfSadQ%3D%3D&lsparams=met%2Cmh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Crms%2Cinitcwndbps&lsig=ACuhMU0wRQIgVVOjT26wVMShS_LC3_zwe2gZ5nazA-XweEfWKPgHpTsCIQD_PPw1hNBKy2b4WHY-ys5MuQIDV1O03EResAAx9u1deQ%3D%3D', '-t', '10', '-vf', 'crop=256:256:(in_w-256)/2:(in_h-256)/2', '-c:v', 'libx264', '-preset', 'veryfast', '-crf', '23', '-c:a', 'copy', 'data_set_try1/processed/xkjOXJDOOFo_162s/segment.mp4']' returned non-zero exit status 8.
# 🔄 Processing OVBQuUJhtfg @ 30s …
# ERROR: [youtube] OVBQuUJhtfg: Video unavailable
# ⚠️ Erreur pour OVBQuUJhtfg@30s : ERROR: [youtube] OVBQuUJhtfg: Video unavailable
# 🔄 Processing CeTbzVsGfRw @ 30s …
# ⚠️ Erreur pour CeTbzVsGfRw@30s : Command '['ffmpeg', '-ss', '00:00:30', '-i', 'https://rr1---sn-nfpuji-1gil.googlevideo.com/videoplayback?expire=1745875959&ei=l58PaKy-DubO6dsPirbkkA4&ip=2001%3A620%3A618%3A5c0%3A2%3A80b3%3A0%3A3d3&id=o-AEDAqHzY1eI8IHuwtz07WXJbmYxkouaD9pPBQ9vHVzBU&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1745854359%2C&mh=tr&mm=31%2C29&mn=sn-nfpuji-1gil%2Csn-1gi7znek&ms=au%2Crdu&mv=m&mvi=1&pcm2cms=yes&pl=32&rms=au%2Cau&initcwndbps=4430000&bui=AecWEAbATGoEG9GzMuEx9rAbfYDsnJCjkTabwaNrnsedkpbnsBxWOXbqSyn4-pWtOSlOipvqGUKAcjnB&vprv=1&svpuc=1&mime=video%2Fmp4&ns=7UJT2Inmb4lPg4tOG1GMDQEQ&rqh=1&cnr=14&ratebypass=yes&dur=46.068&lmt=1744555934425586&mt=1745853906&fvip=1&lmw=1&c=TVHTML5&sefc=1&txp=8208224&n=3r5FztHlRrxRKA&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cbui%2Cvprv%2Csvpuc%2Cmime%2Cns%2Crqh%2Ccnr%2Cratebypass%2Cdur%2Clmt&sig=AJfQdSswRQIhAO08xOnwr_dyRsJPE8RBnQtIiIDDVEpIlcuMFxwGD0OZAiA8GsQXnhFjjEifEMNtUjCiDPiCDl4JT3jDZsWVm_MVoA%3D%3D&lsparams=met%2Cmh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Crms%2Cinitcwndbps&lsig=ACuhMU0wQwIfVAU3Zd90CI0JuvbxZXu52oV9DLmWE9YNdwQ-gfXV8gIgCUfM7vHlaPbXGZ-WjKaimV2KKbAbX49mglu_Iw6ZlEs%3D', '-t', '10', '-vf', 'crop=256:256:(in_w-256)/2:(in_h-256)/2', '-c:v', 'libx264', '-preset', 'veryfast', '-crf', '23', '-c:a', 'copy', 'data_set_try1/processed/CeTbzVsGfRw_30s/segment.mp4']' returned non-zero exit status 8.
# ✅ Tout est prêt dans data_set_try1/processed
