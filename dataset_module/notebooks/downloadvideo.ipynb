# %%
# Cell 1 — Imports & configuration
import os
import shutil
import subprocess
import time
import pandas as pd
from yt_dlp import YoutubeDL

OUTPUT_DIR   = "data_set_try1/videos"                             # dossier de sortie
CSV_LABELS   = "data_set_try1/dataset/labels_semantic_clusters.csv"
CSV_DATA     = "data_set_try1/dataset/vggsound.csv"
CLUSTER      = '3'                                  # numéro de cluster
DURATION_SEC = 10                                   # durée du clip en secondes

# Vérifions qu’on a bien ffmpeg dispo
if shutil.which("ffmpeg") is None:
    raise RuntimeError("⚠️ ffmpeg n'est pas installé — indispensable pour ce script.")

# %%
# Cell 2 — Fonctions utilitaires
def sec_to_timestamp(s: int) -> str:
    """Convertit un entier de secondes en 'HH:MM:SS'."""
    return time.strftime("%H:%M:%S", time.gmtime(s))

def download_segment_fast(video_id: str, start_sec: int, duration: int, dest_folder: str):
    """
    1) Récupère l’URL du flux MP4 (360p, conteneur mp4).
    2) Lance ffmpeg avec -ss et -t pour ne tirer que la portion souhaitée.
    """
    os.makedirs(dest_folder, exist_ok=True)
    url = f"https://www.youtube.com/watch?v={video_id}"

    # 1) Extraction de l’URL directe du flux MP4 (audio+vidéo) H264≤360p
    ydl_opts = {
        'format': 'best[height<=360][ext=mp4]',
        'quiet': True,
        'skip_download': True,
    }
    with YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(url, download=False)
        stream_url = info['url']

    # 2) Construction du nom et des timestamps
    t0 = sec_to_timestamp(start_sec)
    output_name = f"{video_id}_{start_sec}s.mp4"
    output_path = os.path.join(dest_folder, output_name)

    # 3) Appel ffmpeg : -ss avant -i pour seek rapide, -t pour durée, -c copy pour pas ré-encoder
    cmd = [
        'ffmpeg',
        '-ss', t0,
        '-i', stream_url,
        '-t', str(duration),
        '-c', 'copy',
        output_path
    ]
    subprocess.run(cmd, check=True)

def download_segment_crop256(video_id: str, start_sec: int, duration: int, dest_folder: str):
    """
    1) Récupère l’URL du flux MP4 (360p).
    2) Coupe le segment [start_sec, start_sec+duration].
    3) Croppe en 256×256 centré.
    4) Sort en MP4 (H.264+AAC).
    """
    os.makedirs(dest_folder, exist_ok=True)
    url = f"https://www.youtube.com/watch?v={video_id}"

    # Extraction de l’URL directe du flux MP4
    ydl_opts = {'format': 'best[height<=360][ext=mp4]', 'quiet': True, 'skip_download': True}
    with YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(url, download=False)
        stream_url = info['url']

    # Timestamp de début
    t0 = sec_to_timestamp(start_sec)
    output_name = f"{video_id}_{start_sec}s_256crop.mp4"
    output_path = os.path.join(dest_folder, output_name)

    # ffmpeg : -ss avant -i pour seek rapide, -t pour durée, -vf pour crop, 
    # -c:v libx264 pour encoder, -preset veryfast pour vitesse, -crf 23 qualité raisonnable, -c:a copy
    cmd = [
        'ffmpeg',
        '-ss', t0,
        '-i', stream_url,
        '-t', str(duration),
        '-vf', 'crop=256:256:(in_w-256)/2:(in_h-256)/2',
        '-c:v', 'libx264',
        '-preset', 'veryfast',
        '-crf', '23',
        '-c:a', 'copy',
        output_path
    ]
    subprocess.run(cmd, check=True)

# %%
# Cell 3 — Lecture & filtrage du dataset
labels_df = pd.read_csv(CSV_LABELS, header=None,
                        names=['label','count','cluster'])
used_labels = labels_df[labels_df['cluster']==CLUSTER]['label'].values

data_df = pd.read_csv(CSV_DATA, header=None,
                      names=['video_id','start_sec','label','split'])
sub_df = data_df[data_df['label'].isin(used_labels)].sample(10, random_state=42)

# %%
labels_df

# %%
# Cell 4 — Boucle de téléchargement
for vid, start, label, split in sub_df.itertuples(index=False):
    real_end = min(start + DURATION_SEC, start + DURATION_SEC)  # juste pour l'affichage
    print(f"▶️ {vid} @ {start}s → +{DURATION_SEC}s …")
    try:
        download_segment_crop256(vid, int(start), DURATION_SEC, OUTPUT_DIR)
    except Exception as e:
        print(f"⚠️ Erreur pour {vid}@{start}s : {e}")

print("✅ Tous les segments (10 s) sont prêts en MP4 dans", OUTPUT_DIR)

# %% [markdown]
# # THIS PART TRY TO CREATE THE DATASET ON THE FLY WHILE DOWNLOADING THE VIDEO

# %%
import os, shutil, subprocess, time, sys
import pandas as pd
import numpy as np
from pydub import AudioSegment
from yt_dlp import YoutubeDL,DownloadError
import cv2
import shutil

OUTPUT_DIR   = "data_set_try1/processed"       # dossier racine de sortie
CSV_LABELS   = "data_set_try1/dataset/labels_semantic_clusters.csv"
CSV_DATA     = "data_set_try1/dataset/vggsound.csv"
CLUSTER      = '3'
DURATION_SEC = 10

# check ffmpeg
if shutil.which("ffmpeg") is None:
    raise RuntimeError("⚠️ ffmpeg n'est pas installé — indispensable.")
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
#CLEAN PROCESSED FILE (TO REMOVE JUST USEFULL WHILE DEBUGING)
OUTPUT_DIR = "data_set_try1/processed"

# Supprime tous les sous-dossiers de OUTPUT_DIR
for name in os.listdir(OUTPUT_DIR):
    path = os.path.join(OUTPUT_DIR, name)
    if os.path.isdir(path):
        shutil.rmtree(path)

# %%
# Cell 2 — Fonctions utilitaires

def sec_to_timestamp(s: int) -> str:
    return time.strftime("%H:%M:%S", time.gmtime(s))

def download_segment(video_id: str, start: int, dur: int, out_dir: str) -> str:
    """Récupère le segment mp4 (audio+vidéo) et renvoie le chemin."""
    url = f"https://www.youtube.com/watch?v={video_id}"
    ydl_opts = {'format': 'best[height<=360][ext=mp4]', 'quiet': True, 'skip_download': True}
    with YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(url, download=False)
        stream_url = info['url']
    t0 = sec_to_timestamp(start)
    segment_path = os.path.join(out_dir, "segment.mp4")
    cmd = [
        'ffmpeg', '-ss', t0, '-i', stream_url,
        '-t', str(dur), '-c', 'copy',
        segment_path
    ]
    subprocess.run(cmd, check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    return segment_path

def download_segment_copy(video_id: str, start: int, dur: int, out_dir: str) -> str:
    """Récupère le segment mp4 (audio+vidéo) en copiant tout (pas de transcodage)."""
    url = f"https://www.youtube.com/watch?v={video_id}"
    ydl_opts = {
        'format': 'best[height<=360][ext=mp4]',
        'quiet': True,
        'skip_download': True,
    }
    with YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(url, download=False)
        stream_url = info['url']
    t0 = sec_to_timestamp(start)
    raw_path = os.path.join(out_dir, "raw_segment.mp4")
    cmd = [
        'ffmpeg',
        '-ss', t0,           # SEEK avant l'input → range request
        '-i', stream_url,    # URL YouTube
        '-t', str(dur),
        '-c', 'copy',        # copie brute audio+vidéo
        raw_path
    ]
    subprocess.run(cmd, check=True)
    return raw_path


def download_segment_crop256_macos(video_id: str, start_sec: int, duration: int, dest_folder: str) -> str:
    os.makedirs(dest_folder, exist_ok=True)

    # ⚙️ 1) ON DÉCOUPE d'abord en copy
    raw = download_segment_copy(video_id, start_sec, duration, dest_folder)
    if not os.path.exists(raw):
        return ""

    # ⚙️ 2) puis on recadre localement
    out_path = os.path.join(dest_folder, "segment.mp4")
    cmd = [
        'ffmpeg',
        '-i',      raw,
        '-threads','0',
        '-vf',     'crop=256:256:(in_w-256)/2:(in_h-256)/2',
        '-c:v',    'hevc_videotoolbox',  # HEVC via VideoToolbox
        '-b:v',    '1800k',              # ~1.8 Mbps, ajustez selon la qualité souhaitée
        '-c:a',    'copy',
        out_path
    ]
    subprocess.run(cmd, check=True)
    return out_path


def download_segment_crop256_cluster(video_id: str, start_sec: int, duration: int, dest_folder: str) -> str:
    os.makedirs(dest_folder, exist_ok=True)
    url = f"https://www.youtube.com/watch?v={video_id}"

    try:
        info = ydl.extract_info(url, download=False)
    except DownloadError as e:
        print(f"[Erreur] Impossible de récupérer {video_id} : {e}")
        return ""

    stream_url = info['url']
    t0 = sec_to_timestamp(start_sec)
    out_path = os.path.join(dest_folder, "segment.mp4")

    # GPU accel. avec NVENC + multithreading
    cmd = [
        'ffmpeg',
        '-hwaccel', 'cuda',          # initialise CUDA
        '-i', stream_url,
        '-threads', '0',
        '-ss', t0,
        '-t', str(duration),
        '-vf', 'crop=256:256:(in_w-256)/2:(in_h-256)/2',
        '-c:v', 'h264_nvenc',        # encodeur NVIDIA
        '-preset', 'p1',             # preset NVENC (p1 = fastest)
        '-rc', 'vbr_hq',             # mode rate control haute qualité
        '-cq', '23',                 # qualité visuelle (comme crf)
        '-c:a', 'copy',
        out_path
    ]
    subprocess.run(cmd, check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    return out_path


def analyze_audio_max_timestamp(video_path: str) -> float:
    """Retourne en secondes le point de volume max dans segment.mp4."""
    audio = AudioSegment.from_file(video_path)
    mono  = audio.set_channels(1)
    arr   = np.array(mono.get_array_of_samples())
    idx   = int(np.argmax(np.abs(arr)))
    return idx / mono.frame_rate

def sample_frames(video_path, num_samples=30):
    cap = cv2.VideoCapture(video_path)
    total = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    indices = np.linspace(0, total - 1, num=num_samples, dtype=int)
    frames = []
    for idx in indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, img = cap.read()
        if ret:
            frames.append(img)
    cap.release()
    return frames

def extract_best_thumbnail(video_path: str, ts: float, out_path: str):
    """
    => Prend plusieurs frames autour de ts (±0.5s), calcule la variance
       du Laplacien (proxy pour la netteté), choisit la meilleure,
       fait une égalisation d’histogramme sur la luminance, et sauve.
    """
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise RuntimeError(f"Impossible d'ouvrir {video_path}")
    fps      = cap.get(cv2.CAP_PROP_FPS) or 25
    frame_ct = cap.get(cv2.CAP_PROP_FRAME_COUNT)
    duration = frame_ct / fps

    # offsets en secondes autour du pic
    offsets = [-0.5, -0.25, 0, 0.25, 0.5]
    best_score = -1
    best_frame = None

    for off in offsets:
        t = min(max(ts + off, 0), duration)
        cap.set(cv2.CAP_PROP_POS_MSEC, t * 1000)
        ret, frame = cap.read()
        if not ret: 
            continue
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        score = cv2.Laplacian(gray, cv2.CV_64F).var()
        if score > best_score:
            best_score, best_frame = score, frame

    cap.release()

    if best_frame is None:
        raise RuntimeError("Aucune frame extraite pour la thumbnail")

    # égalisation de l'histogramme sur le canal Y de YUV
    yuv = cv2.cvtColor(best_frame, cv2.COLOR_BGR2YUV)
    yuv[:,:,0] = cv2.equalizeHist(yuv[:,:,0])
    enhanced = cv2.cvtColor(yuv, cv2.COLOR_YUV2BGR)

    cv2.imwrite(out_path, enhanced)

def strip_audio(video_path: str, out_path: str):
    """Génère video_no_audio.mp4."""
    cmd = ['ffmpeg', '-i', video_path, '-c', 'copy', '-an', out_path]
    subprocess.run(cmd, check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

def extract_audio(video_path: str, out_path: str):
    """Génère audio.m4a."""
    cmd = ['ffmpeg', '-i', video_path, '-vn', '-c:a', 'copy', out_path]
    subprocess.run(cmd, check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

def process_one(vid: str, start: int, label : str):
    """Orchestre tout pour un segment."""
    name = f"{vid}_{start}s"
    folder = os.path.join(OUTPUT_DIR, name)
    os.makedirs(folder, exist_ok=True)

    seg = download_segment_crop256_macos(vid, start, DURATION_SEC, folder)
    ts  = analyze_audio_max_timestamp(seg)
    # extract_best_thumbnail(seg, ts, os.path.join(folder, "thumbnail.jpg"))
    
    extract_best_thumbnail(
        seg,
        start,
        os.path.join(folder, "thumbnail.jpg"),
    )

    strip_audio(seg,  os.path.join(folder, "video_no_audio.mp4"))
    extract_audio(seg, os.path.join(folder, "audio.m4a"))

# %%
# Cell 3 — Lecture & filtrage du dataset
labels_df = pd.read_csv(CSV_LABELS, header=None,
                        names=['label','count','cluster'])
used_labels = labels_df[labels_df['cluster']==CLUSTER]['label'].values

data_df = pd.read_csv(CSV_DATA, header=None,
                      names=['video_id','start_sec','label','split'])
sub_df = data_df[data_df['label'].isin(used_labels)].sample(10, random_state=42)

# %%
# Cell 4 — Traitement en boucle
for vid, start, label ,*_ in sub_df.itertuples(index=False):
    print(f"🔄 Processing {vid} @ {start}s …")
    try:
        process_one(vid, int(start), label)
    except Exception as e:
        print(f"⚠️ Erreur pour {vid}@{start}s : {e}")

print("✅ Tout est prêt dans", OUTPUT_DIR)
# Out:
# 🔄 Processing 5PVKgUGg0LQ @ 450s …
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with clang version 14.0.6
#   configuration: --prefix=/opt/anaconda3/envs/dataloader --cc=arm64-apple-darwin20.0.0-clang --ar=arm64-apple-darwin20.0.0-ar --nm=arm64-apple-darwin20.0.0-nm --ranlib=arm64-apple-darwin20.0.0-ranlib --strip=arm64-apple-darwin20.0.0-strip --disable-doc --enable-swresample --enable-swscale --enable-openssl --enable-libxml2 --enable-libtheora --enable-demuxer=dash --enable-postproc --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libdav1d --enable-zlib --enable-libaom --enable-pic --enable-shared --disable-static --disable-gpl --enable-version3 --disable-sdl2 --enable-libopenh264 --enable-libopus --enable-libmp3lame --enable-libopenjpeg --enable-libvorbis --enable-pthreads --enable-libtesseract --enable-libvpx --enable-librsvg
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr1---sn-nfpuji-1gil.googlevideo.com/videoplayback?expire=1745962470&ei=hvEQaLePILWL6dsPkYjtmQE&ip=2001%3A620%3A618%3A5c0%3A2%3A80b3%3A0%3A547&id=o-ACqU4k0XtO7baYQpLVIqiQeERrEDxQK6yHJbjq62BEm5&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&met=1745940870%2C&mh=7z&mm=31%2C29&mn=sn-nfpuji-1gil%2Csn-1gi7znek&ms=au%2Crdu&mv=m&mvi=1&pcm2cms=yes&pl=32&rms=au%2Cau&initcwndbps=3146250&bui=AecWEAbLINxPLHd7vIv1uUPFex1Eh0sTjAJd5o5EQeFrQ9e_jtD04DVL-XmQmWR-k6H_kUyuNnez5V7L&vprv=1&svpuc=1&mime=video%2Fmp4&ns=u5DEuKzh7Z94YDJxmlpazjgQ&rqh=1&cnr=14&ratebypass=yes&dur=664.926&lmt=1743737791279412&mt=1745940561&fvip=1&lmw=1&c=TVHTML5&sefc=1&txp=5438534&n=rszcY5K3iVHeUg&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cbui%2Cvprv%2Csvpuc%2Cmime%2Cns%2Crqh%2Ccnr%2Cratebypass%2Cdur%2Clmt&sig=AJfQdSswRAIgXhW296nRlRhbkx2sF2ICb4eQMQYA2_ftVcfxvp_j63wCIFU_2nkYgoC2vAVev9ZSNwubPbRf7lDzgSaw9lFOB42M&lsparams=met%2Cmh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Crms%2Cinitcwndbps&lsig=ACuhMU0wRQIhAMYk50bDZYP7o9UJqv5RvNLnA5cZsPnNSQNOY3I4s75rAiAg4Z334MqLnALT_YjfpV0gS2Iv00zQGfAKjns4OKykww%3D%3D':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2024-03-27T01:40:42.000000Z
#   Duration: 00:11:04.88, start: 0.000000, bitrate: 372 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360 [SAR 1:1 DAR 16:9], 240 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2024-03-27T01:40:42.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/26/2024.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2024-03-27T01:40:42.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/26/2024.
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'data_set_try1/processed/5PVKgUGg0LQ_450s/raw_segment.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360 [SAR 1:1 DAR 16:9], q=2-31, 240 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#     Metadata:
#       creation_time   : 2024-03-27T01:40:42.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/26/2024.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2024-03-27T01:40:42.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/26/2024.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x12900ee70] video:499kB audio:227kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.222333%
# size=     742kB time=00:00:09.99 bitrate= 608.4kbits/s speed=54.1x
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with clang version 14.0.6
#   configuration: --prefix=/opt/anaconda3/envs/dataloader --cc=arm64-apple-darwin20.0.0-clang --ar=arm64-apple-darwin20.0.0-ar --nm=arm64-apple-darwin20.0.0-nm --ranlib=arm64-apple-darwin20.0.0-ranlib --strip=arm64-apple-darwin20.0.0-strip --disable-doc --enable-swresample --enable-swscale --enable-openssl --enable-libxml2 --enable-libtheora --enable-demuxer=dash --enable-postproc --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libdav1d --enable-zlib --enable-libaom --enable-pic --enable-shared --disable-static --disable-gpl --enable-version3 --disable-sdl2 --enable-libopenh264 --enable-libopus --enable-libmp3lame --enable-libopenjpeg --enable-libvorbis --enable-pthreads --enable-libtesseract --enable-libvpx --enable-librsvg
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'data_set_try1/processed
mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: hevc (hev1 / 0x31766568), yuv420p(tv, bt709, progressive), 256x256 [SAR 1:1 DAR 1:1], q=2-31, 1800 kb/s, 29.97 fps, 30k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc. Created on: 04/30/2024.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 hevc_videotoolbox
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc. Created on: 04/30/2024.
#       vendor_id       : [0][0][0][0]
# [out#0/mp4 @ 0x12d604740] video:2224kB audio:172kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.422346%
# frame=  300 fps=0.0 q=-0.0 Lsize=    2406kB time=00:00:09.98 bitrate=1974.2kbits/s speed=18.2x
# ⚠️ Erreur pour CeTbzVsGfRw@30s : Aucune frame extraite pour la thumbnail
# ✅ Tout est prêt dans data_set_try1/processed

# %%
import json
import csv
from pathlib import Path

def convert_json_to_csv(json_path: str, csv_path: str) -> None:
    """
    Convert a list of annotation records in JSON format to CSV.

    Each record should contain:
      - video clip name (keys: 'video_clip_name', 'video_clip', or 'name')
      - class label (keys: 'class' or 'label')
      - bounding box dict with keys: 'Xmin', 'Ymin', 'Xmax', 'Ymax'
    """
    # Load JSON
    with open(json_path, 'r', encoding='utf-8') as jf:
        records = json.load(jf)

    # Prepare CSV output
    with open(csv_path, 'w', newline='', encoding='utf-8') as cf:
        writer = csv.writer(cf)
        # Header row
        writer.writerow(['video_clip_name', 'class', 'Xmin', 'Ymin', 'Xmax', 'Ymax'])

        for rec in records:
            # Extract fields with flexible key names
            print(rec)
            video_name = rec.get('file')
            class_label = rec.get('class')
            bbox = rec.get('bbox')
            bbox = bbox[0]

            # Skip if no bounding box
            if not bbox:
                continue

            xmin = bbox[0]
            ymin = bbox[1]
            xmax = bbox[2]
            ymax = bbox[3]

            writer.writerow([video_name, class_label, xmin, ymin, xmax, ymax])

    print(f"Converted {len(records)} records from '{json_path}' → '{csv_path}'.")


# Define input and output paths
input_json = 'data_set_try1/dataset/vggss.json'
output_csv = 'data_set_try1/dataset/vggss.csv'

# Run conversion
convert_json_to_csv(input_json, output_csv)
# Out:
# {'file': 'zpWuikVorYg_000032', 'class': 'elk bugling', 'bbox': [[0.403125, 0.253125, 0.6, 0.75]]}
# {'file': 'gEvCUcZ6w88_000030', 'class': 'female speech, woman speaking', 'bbox': [[0.45, 0.190625, 0.584375, 0.47812499999999997]]}
# {'file': 'JIemsK_0lXc_000364', 'class': 'playing bass drum', 'bbox': [[0.03125, 0.3625, 0.36875, 0.9875]]}
# {'file': 'RgyqhpOJFM4_000030', 'class': 'playing cello', 'bbox': [[0.396875, 0.021875, 0.6875, 0.99375]]}
# {'file': '3MUeg3nD2OU_000120', 'class': 'playing acoustic guitar', 'bbox': [[0.303125, 0.0, 0.953125, 1.0]]}
# {'file': 'iUtE4nRvBsM_000040', 'class': 'people coughing', 'bbox': [[0.29375, 0.03125, 0.73125, 0.578125]]}
# {'file': '1cxvg7qu0G0_000070', 'class': 'lighting firecrackers', 'bbox': [[0.025, 0.271875, 0.38125000000000003, 0.85625]]}
# {'file': '16CvcIXIjzQ_000332', 'class': 'chinchilla barking', 'bbox': [[0.278125, 0.003125, 0.8500000000000001, 0.59375]]}
# {'file': 'gg6yoeBoYxg_000000', 'class': 'children shouting', 'bbox': [[0.13125, 0, 1.0, 0.31875]]}
# {'file': 'ORaz32CQ29k_000130', 'class': 'coyote howling', 'bbox': [[0.121875, 0.171875, 0.6, 0.853125], [0.765625, 0.275, 0.984375, 0.565625]]}
# {'file': '1FnA3w94zXI_000030', 'class': 'tapping guitar', 'bbox': [[0.003125, 0.153125, 0.984375, 0.8500000000000001]]}
# {'file': '-_QPd-VskKY_000030', 'class': 'mouse squeaking', 'bbox': [[0.346875, 0.065625, 0.70625, 0.68125]]}
# {'file': 'SHk3gJAnm8U_000529', 'class': 'people sniggering', 'bbox': [[0.66875, 0.075, 0.990625, 0.8218749999999999]]}
# {'file': 'HOqx0IZGgBk_000286', 'class': 'train whistling', 'bbox': [[0.03125, 0.19375, 0.99375, 0.684375]]}
# {'file': 'ux7HhOxMRE4_000020', 'class': 'dog barking', 'bbox': [[0.15625, 0.146875, 0.8375, 0.990625]]}
# {'file': 'tXLaQKRWM8I_000000', 'class': 'dog baying', 'bbox': [[0.05, 0.321875, 0.303125, 0.58125], [0.10625, 0.515625, 0.5375, 0.953125]]}
# {'file': 'Nluf6HIYXXQ_000030', 'class': 'dog howling', 'bbox': [[0.128125, 0.1625, 0.7375, 0.96875]]}
# {'file': '10YXuv9Go0E_000140', 'class': 'skateboarding', 'bbox': [[0.375, 0.653125, 0.56875, 0.8624999999999999]]}
# {'file': 'qoVQyvJcKkQ_000460', 'class': 'people eating noodle', 'bbox': [[0.40625, 0.0, 0.74375, 0.5875]]}
# {'file': '5qVc9y3TNnY_000030', 'class': 'female singing', 'bbox': [[0.325, 0.1625, 0.60625, 0.515625]]}
# {'file': '9XuTWG0Svls_000041', 'class': 'popping popcorn', 'bbox': [[0.053125, 0.059375, 0.903125, 0.990625]]}
# {'file': 'g0RkIkC2meo_000030', 'class': 'fire truck siren', 'bbox': [[0.46875, 0.159375, 0.809375, 0.7562500000000001]]}
# {'file': 'Jj3Ie49Mzik_000020', 'class': 'people whistling', 'bbox': [[0.403125, 0.540625, 0.63125, 0.74375]]}
# {'file': 'ZedCPKaacjU_000326', 'class': 'airplane', 'bbox': [[0.059375, 0.18125, 0.975, 0.834375]]}
# {'file': 'vf8cYm5yVy4_000026', 'class': 'air horn', 'bbox': [[0.05, 0.03125, 0.953125, 0.734375]]}
# {'file': 'A8gbOIvxvMA_000030', 'class': 'playing cello', 'bbox': [[0.090625, 0.084375, 0.309375, 0.9562499999999999], [0.578125, 0.103125, 0.99375, 0.99375]]}
# {'file': 'ycjnLHuYx7U_000035', 'class': 'playing mandolin', 'bbox': [[0.353125, 0.553125, 0.7406250000000001, 0.990625]]}
# {'file': '1Isq_KJHriU_000016', 'class': 'dog baying', 'bbox': [[0.7375, 0.584375, 0.915625, 0.984375]]}
# {'file': 'pX0Jhk6e2Uw_000030', 'class': 'playing trumpet', 'bbox': [[0.3, 0.31875, 0.6968749999999999, 0.809375]]}
# {'file': 'LDGzSk_vzPo_000260', 'class': 'bird wings flapping', 'bbox': [[0.625, 0.134375, 0.909375, 0.48124999999999996]]}
# {'file': 'XySWOKnenIA_000000', 'class': 'electric grinder grinding', 'bbox': [[0.20625, 0.6125, 0.43125, 0.8406250000000001]]}
# {'file': 'amEW4O2Z350_000035', 'class': 'playing glockenspiel', 'bbox': [[0.0, 0.015625, 1.0, 0.990625]]}
# {'file': 'oswEaAsFXDM_000170', 'class': 'car engine starting', 'bbox': [[0.321875, 0.13125, 0.915625, 0.734375]]}
# {'file': 'N8iIq2UzZLk_000030', 'class': 'playing acoustic guitar', 'bbox': [[0.19375, 0.446875, 0.9, 0.7875000000000001]]}
# {'file': '7RNTXUuCKoQ_000029', 'class': 'children shouting', 'bbox': [[0.3875, 0.5875, 0.53125, 0.765625], [0.571875, 0.590625, 0.73125, 0.7875]]}
# {'file': 'ov4fdnGwzWU_000520', 'class': 'playing trumpet', 'bbox': [[0.38125, 0.340625, 0.5625, 0.89375]]}
# {'file': 'rmL21Z7wZuk_000020', 'class': 'blowtorch igniting', 'bbox': [[0.109375, 0.146875, 0.96875, 0.8156249999999999]]}
# {'file': '8JgqLELdUkY_000030', 'class': 'cat meowing', 'bbox': [[0.33125, 0.23125, 0.784375, 0.96875]]}
# {'file': 'Bgnaur8-fas_000160', 'class': 'playing bongo', 'bbox': [[0.0, 0.453125, 0.80625, 0.76875]]}
# {'file': 'Ii5W65uAeF0_000056', 'class': 'people slurping', 'bbox': [[0.296875, 0.015625, 0.59375, 0.253125]]}
# {'file': 'z6oqPB07X3o_000030', 'class': 'people sniggering', 'bbox': [[0.125, 0.00625, 0.478125, 0.296875]]}
# {'file': 'D3BJuOwltoI_000010', 'class': 'driving motorcycle', 'bbox': [[0.503125, 0.51875, 0.775, 0.9875]]}
# {'file': 'aWgRtDIA2U4_000029', 'class': 'turkey gobbling', 'bbox': [[0.159375, 0.26875, 0.79375, 0.8218749999999999]]}
# {'file': 'd-1th_S4J0U_000000', 'class': 'people belly laughing', 'bbox': [[0.334375, 0.325, 0.628125, 0.7125]]}
# {'file': '_6gpB_Trvo8_000000', 'class': 'car engine starting', 'bbox': [[0.134375, 0.353125, 0.83125, 0.71875]]}
# {'file': 'B7Iab-AC3Dw_000110', 'class': 'playing bass drum', 'bbox': [[0.43125, 0.421875, 0.8343750000000001, 0.78125]]}
# {'file': 'GrACpo7aonA_000030', 'class': 'playing drum kit', 'bbox': [[0.00625, 0.009375, 0.9874999999999999, 0.86875]]}
# {'file': '_QjCOK638vc_000036', 'class': 'parrot talking', 'bbox': [[0.19375, 0.271875, 0.75, 0.98125]]}
# {'file': 'rLa17dibI70_000175', 'class': 'children shouting', 'bbox': [[0.0, 0.215625, 0.20625, 0.65], [0.746875, 0.003125, 0.96875, 0.328125]]}
# {'file': 'aS5eOryeLbM_000210', 'class': 'singing bowl', 'bbox': [[0.15, 0.028125, 0.865625, 0.96875]]}
# {'file': 'TZl2cGkWZL4_000030', 'class': 'dog bow-wow', 'bbox': [[0.196875, 0.4, 0.503125, 0.978125]]}
# {'file': '3sQrJVyxju0_000065', 'class': 'playing mandolin', 'bbox': [[0.0, 0.64375, 0.81875, 0.99375], [0.51875, 0.475, 0.96875, 0.975]]}
# {'file': 'acepdtp7F7Y_000348', 'class': 'people eating apple', 'bbox': [[0.371875, 0.203125, 0.64375, 0.60625]]}
# {'file': 'Cmb7oRnRLio_000034', 'class': 'whale calling', 'bbox': [[0.0, 0.334375, 0.471875, 0.88125]]}
# {'file': 'O9M7RtFP_-Y_000010', 'class': 'playing glockenspiel', 'bbox': [[0.04375, 0.53125, 0.575, 0.9875]]}
# {'file': 'lkLg1kI06UM_000406', 'class': 'slot machine', 'bbox': [[0.071875, 0.05625, 0.8718750000000001, 0.6843750000000001]]}
# {'file': 'd7Xf7brOPzw_000149', 'class': 'cat caterwauling', 'bbox': [[0.459375, 0.265625, 0.903125, 0.921875], [0.075, 0.003125, 0.440625, 0.609375]]}
# {'file': 'CA5iF0mpXFE_000030', 'class': 'playing harmonica', 'bbox': [[0.5125, 0.340625, 0.81875, 0.596875]]}
# {'file': 'v-wAote9cyA_000001', 'class': 'tractor digging', 'bbox': [[0.4, 0.13125, 0.6937500000000001, 0.7218749999999999]]}
# {'file': 'BWlYf-hKucs_000083', 'class': 'people gargling', 'bbox': [[0.703125, 0.378125, 0.890625, 0.678125]]}
# {'file': 'HCmwbTIHIcw_000002', 'class': 'snake hissing', 'bbox': [[0.04375, 0.04375, 0.796875, 0.928125]]}
# {'file': 'Aq58qBpVkv8_000160', 'class': 'people shuffling', 'bbox': [[0.3625, 0.0, 0.7375, 0.83125]]}
# {'file': '7PK3nvCihMk_000011', 'class': 'bull bellowing', 'bbox': [[0.009375, 0.25, 0.728125, 0.8125]]}
# {'file': '4-DcTjFR4qw_000100', 'class': 'car passing by', 'bbox': [[0.5, 0.30625, 0.7625, 0.578125]]}
# {'file': 'bOD-pt3NWYc_000018', 'class': 'ice cream truck, ice cream van', 'bbox': [[0.371875, 0.21875, 0.66875, 0.496875]]}
# {'file': 'miT69L7G9iA_000140', 'class': 'people babbling', 'bbox': [[0.590625, 0.25625, 0.765625, 0.453125], [0.234375, 0.003125, 0.378125, 0.14687499999999998]]}
# {'file': '_UmY2aYt1YQ_000030', 'class': 'race car, auto racing', 'bbox': [[0.48125, 0.375, 0.8, 0.615625]]}
# {'file': 'jR-H47v1arg_000080', 'class': 'pigeon, dove cooing', 'bbox': [[0.23125, 0.16875, 0.7250000000000001, 0.7406250000000001]]}
# {'file': 'pVf84f6xrBw_000070', 'class': 'playing steel guitar, slide guitar', 'bbox': [[0.059375, 0.103125, 0.928125, 0.9875]]}
# {'file': 'qEJ_jxZzt7k_000030', 'class': 'tapping guitar', 'bbox': [[0.175, 0.228125, 0.953125, 0.584375]]}
# {'file': 'Y-qOOR0izlE_000102', 'class': 'helicopter', 'bbox': [[0.128125, 0.246875, 0.95625, 0.703125]]}
# {'file': 'zey5f-NjbtE_000002', 'class': 'people giggling', 'bbox': [[0.334375, 0.05, 0.765625, 0.5281250000000001]]}
# {'file': 'jbH4PifIg-g_000006', 'class': 'playing tambourine', 'bbox': [[0.421875, 0.578125, 0.6625, 0.925]]}
# {'file': 'uz-_ROIn0bM_000035', 'class': 'blowtorch igniting', 'bbox': [[0.0375, 0.371875, 0.865625, 0.80625]]}
# {'file': 'pi2Vyqa-wgE_000087', 'class': 'dinosaurs bellowing', 'bbox': [[0.334375, 0.23125, 0.66875, 0.8656250000000001]]}
# {'file': 'eO8SL6GZeqc_000004', 'class': 'playing glockenspiel', 'bbox': [[0.009375, 0.00625, 0.990625, 0.7843749999999999]]}
# {'file': 'pnsntPDPfxg_000064', 'class': 'penguins braying', 'bbox': [[0.0, 0.0, 0.690625, 1.0]]}
# {'file': '-0BIyqJj9ZU_000030', 'class': 'people belly laughing', 'bbox': [[0.34375, 0.0, 0.678125, 0.734375]]}
# {'file': 'ZwAplWOatRo_000020', 'class': 'people nose blowing', 'bbox': [[0.453125, 0.109375, 0.65625, 0.603125]]}
# {'file': 'nfitcQXx-Y0_000058', 'class': 'gibbon howling', 'bbox': [[0.13125, 0.253125, 0.490625, 0.6343749999999999], [0.59375, 0.2875, 0.909375, 0.66875]]}
# {'file': '3GtvLj8K1F4_000140', 'class': 'playing harmonica', 'bbox': [[0.38125, 0.13125, 0.646875, 0.340625]]}
# {'file': 'bE2g05K-B94_000049', 'class': 'cow lowing', 'bbox': [[0.278125, 0.34375, 0.6375, 0.965625]]}
# {'file': 'RJFdWGEdzP4_000160', 'class': 'fox barking', 'bbox': [[0.0375, 0.146875, 0.6, 0.978125]]}
# {'file': 'EUy-RsUXJ00_000030', 'class': 'owl hooting', 'bbox': [[0.340625, 0.0375, 0.8343750000000001, 0.540625]]}
# {'file': 'eeiDM1H_Y-w_000020', 'class': 'toilet flushing', 'bbox': [[0.0, 0.00625, 0.953125, 0.959375]]}
# {'file': 'B-ABbng7Zo4_000508', 'class': 'barn swallow calling', 'bbox': [[0.0, 0.0, 0.78125, 0.915625], [0.646875, 0.08125, 0.90625, 0.7625000000000001]]}
# {'file': 'AznWFbIOSZw_000030', 'class': 'car engine knocking', 'bbox': [[0.49375, 0.0, 0.9375, 0.546875]]}
# {'file': 'wVVBhbrnj9s_000040', 'class': 'people sobbing', 'bbox': [[0.41875, 0.321875, 0.5625, 0.525]]}
# {'file': '2_RltCGlGOA_000010', 'class': 'playing piano', 'bbox': [[0.05625, 0.721875, 0.41875, 0.9750000000000001]]}
# {'file': '1hoUEfsTmdE_000030', 'class': 'female singing', 'bbox': [[0.265625, 0.13125, 0.53125, 0.40625]]}
# {'file': 'bSItOIS0k5w_000008', 'class': 'playing guiro', 'bbox': [[0.415625, 0.0125, 0.8500000000000001, 0.8843749999999999]]}
# {'file': 'LyravGP_Li8_000264', 'class': 'electric shaver, electric razor shaving', 'bbox': [[0.153125, 0.14375, 0.653125, 0.9906250000000001]]}
# {'file': '1WLMVX_Y2Pk_000018', 'class': 'elephant trumpeting', 'bbox': [[0.303125, 0.015625, 0.84375, 0.75]]}
# {'file': 'Swien0oGl7o_000090', 'class': 'playing banjo', 'bbox': [[0.028125, 0.084375, 0.98125, 0.96875]]}
# {'file': 'Rj0cmUyZfR4_000030', 'class': 'mouse squeaking', 'bbox': [[0.228125, 0.03125, 0.7312500000000001, 0.846875]]}
# {'file': '_L5Jp1l3kMQ_000061', 'class': 'elephant trumpeting', 'bbox': [[0.00625, 0.00625, 0.94375, 0.9375]]}
# {'file': 'XaIep0xC8BA_000117', 'class': 'playing timbales', 'bbox': [[0.20625, 0.521875, 0.809375, 0.965625]]}
# {'file': '_XA3BaNyf4Q_000069', 'class': 'playing violin, fiddle', 'bbox': [[0.221875, 0.4625, 0.98125, 0.990625]]}
# {'file': 'cD7zMUwX7T4_000038', 'class': 'playing violin, fiddle', 'bbox': [[0.0625, 0.65625, 0.359375, 0.96875]]}
# {'file': 'lNEMzNU9Unc_000080', 'class': 'wood thrush calling', 'bbox': [[0.5, 0.346875, 0.590625, 0.684375]]}
# {'file': 'HfnGMq0S-vo_000019', 'class': 'popping popcorn', 'bbox': [[0.071875, 0.00625, 0.921875, 0.953125]]}
# {'file': 'EJJx3eIB6ro_000081', 'class': 'hedge trimmer running', 'bbox': [[0.171875, 0.0125, 0.621875, 0.7531249999999999]]}
# {'file': '_peXjzFQ2_c_000030', 'class': 'playing trumpet', 'bbox': [[0.3875, 0.16875, 0.98125, 0.7749999999999999]]}
# {'file': 'vkxPLFRLAy0_000000', 'class': 'fox barking', 'bbox': [[0.025, 0.503125, 0.384375, 0.909375]]}
# {'file': 'bzRimnuUqVc_000017', 'class': 'ice cream truck, ice cream van', 'bbox': [[0.009375, 0.209375, 0.9875, 0.515625]]}
# {'file': '0jy-sVREk4o_000030', 'class': 'horse clip-clop', 'bbox': [[0.215625, 0.19375, 0.60625, 0.990625]]}
# {'file': 'EhlXJGEcuBU_000010', 'class': 'playing tambourine', 'bbox': [[0.215625, 0.075, 0.984375, 0.7843749999999999]]}
# {'file': '6xEHP-C-ZuU_000030', 'class': 'reversing beeps', 'bbox': [[0.3, 0.25, 0.4875, 0.525]]}
# {'file': '-E5o64ACjm0_000017', 'class': 'lathe spinning', 'bbox': [[0.253125, 0.290625, 0.878125, 0.5]]}
# {'file': 'wGms6MZt-vU_000040', 'class': 'people finger snapping', 'bbox': [[0.43125, 0.41875, 0.65625, 0.884375]]}
# {'file': 'SCxlAcrMark_000021', 'class': 'cuckoo bird calling', 'bbox': [[0.296875, 0.54375, 0.4875, 0.91875]]}
# {'file': 'Bpw53tN6h8E_000030', 'class': 'singing bowl', 'bbox': [[0.44375, 0.20625, 0.9874999999999999, 0.76875]]}
# {'file': 'Mel-OwQFWmo_000130', 'class': 'railroad car, train wagon', 'bbox': [[0.003125, 0.0, 0.18437499999999998, 0.98125]]}
# {'file': 'MNEuyIAtj3U_000172', 'class': 'cow lowing', 'bbox': [[0.046875, 0.31875, 0.9625, 0.828125]]}
# {'file': 'ff21Bursam0_000160', 'class': 'cattle mooing', 'bbox': [[0.3, 0.103125, 0.559375, 0.45625000000000004]]}
# {'file': '1vrR6Im_RDo_000030', 'class': 'female singing', 'bbox': [[0.2875, 0.103125, 0.66875, 0.68125]]}
# {'file': 'MI6mYvpTgCM_000083', 'class': 'alarm clock ringing', 'bbox': [[0.565625, 0.16875, 0.953125, 0.859375]]}
# {'file': 'pgQxDv8Iugo_000160', 'class': 'people eating noodle', 'bbox': [[0.45, 0.0125, 0.8, 0.5718749999999999]]}
# {'file': 'Slcg717UTrM_000004', 'class': 'cat growling', 'bbox': [[0.184375, 0.034375, 0.7906249999999999, 0.99375]]}
# {'file': '7xkj4XqaynU_000002', 'class': 'crow cawing', 'bbox': [[0.29375, 0.25, 0.9156249999999999, 0.871875]]}
# {'file': 'AKxm4V3OylU_000030', 'class': 'lions roaring', 'bbox': [[0.24375, 0.065625, 0.675, 0.9593750000000001]]}
# {'file': 'G7qe64jM9zs_000200', 'class': 'railroad car, train wagon', 'bbox': [[0.40625, 0.0625, 0.696875, 0.709375]]}
# {'file': 'fc9x20wj8ss_000076', 'class': 'telephone bell ringing', 'bbox': [[0.396875, 0.028125, 0.69375, 0.9125]]}
# {'file': 'JefjXywAVzs_000181', 'class': 'telephone bell ringing', 'bbox': [[0.075, 0.028125, 0.8156249999999999, 0.8937499999999999]]}
# {'file': 'NXeVBvS5cxQ_000030', 'class': 'typing on computer keyboard', 'bbox': [[0.021875, 0.190625, 0.984375, 0.9468749999999999]]}
# {'file': 'GNYKzDo4w7w_000110', 'class': 'machine gun shooting', 'bbox': [[0.396875, 0.271875, 0.93125, 0.9718749999999999]]}
# {'file': 'RF3rog2YjYw_000030', 'class': 'baby laughter', 'bbox': [[0.33125, 0.2625, 0.621875, 0.6875]]}
# {'file': 'HS28EUWt8dE_000110', 'class': 'people screaming', 'bbox': [[0.18125, 0.0, 0.59375, 0.603125]]}
# {'file': 'ImhA1R3CLI4_000480', 'class': 'people slurping', 'bbox': [[0.421875, 0.0, 0.740625, 0.271875]]}
# {'file': 'ktis2aZfphM_000010', 'class': 'playing cello', 'bbox': [[0.128125, 0.0, 0.8125, 0.99375]]}
# {'file': '-hedbpc8T0E_000030', 'class': 'people babbling', 'bbox': [[0.265625, 0.065625, 0.70625, 0.80625]]}
# {'file': 'X76DCP7SCR0_000150', 'class': 'helicopter', 'bbox': [[0.36875, 0.25625, 0.61875, 0.521875]]}
# {'file': 'YNNepx1HYM8_000031', 'class': 'parrot talking', 'bbox': [[0.0, 0.20625, 0.534375, 0.9937499999999999]]}
# {'file': 'xoXTlNWkC7w_000170', 'class': 'playing congas', 'bbox': [[0.553125, 0.4625, 0.990625, 0.7875000000000001], [0.103125, 0.325, 0.51875, 0.665625]]}
# {'file': 'Le4cUq4dLUI_000030', 'class': 'engine accelerating, revving, vroom', 'bbox': [[0.01875, 0.540625, 0.2375, 0.984375]]}
# {'file': 'mFD6P7We2ww_000081', 'class': 'telephone bell ringing', 'bbox': [[0.065625, 0.05625, 0.434375, 0.99375]]}
# {'file': 'K1ASf4xAexc_000030', 'class': 'parrot talking', 'bbox': [[0.015625, 0.325, 0.653125, 0.6937500000000001]]}
# {'file': 'tQi00qSZC60_000031', 'class': 'baltimore oriole calling', 'bbox': [[0.13125, 0.49375, 0.515625, 0.95]]}
# {'file': 'HQSHJVH2x4w_000024', 'class': 'lathe spinning', 'bbox': [[0.10625, 0.234375, 0.934375, 0.80625]]}
# {'file': 'yO5YnmljmoQ_000001', 'class': 'children shouting', 'bbox': [[0.296875, 0.23125, 0.4, 0.484375]]}
# {'file': 'Xx2YziXzVkg_000030', 'class': 'dog growling', 'bbox': [[0.0375, 0.16875, 0.765625, 0.746875]]}
# {'file': 'RYO6ukdw9PM_000085', 'class': 'cat caterwauling', 'bbox': [[0.025, 0.190625, 0.53125, 0.765625]]}
# {'file': 'bSpAlQLisrI_000030', 'class': 'pigeon, dove cooing', 'bbox': [[0.00625, 0.190625, 0.37187499999999996, 0.690625], [0.590625, 0.134375, 0.803125, 0.596875]]}
# {'file': 'UWFjhEYXbbU_000009', 'class': 'cricket chirping', 'bbox': [[0.396875, 0.5375, 0.521875, 0.6593749999999999]]}
# {'file': '030h_KwNm-g_000003', 'class': 'sheep bleating', 'bbox': [[0.125, 0.28125, 0.78125, 0.753125]]}
# {'file': 'qNj8RLCaoL4_000446', 'class': 'disc scratching', 'bbox': [[0.234375, 0.209375, 0.7375, 0.890625]]}
# {'file': 'NE_DQerjrVU_000020', 'class': 'playing hammond organ', 'bbox': [[0.065625, 0.06875, 0.9281250000000001, 0.9375]]}
# {'file': 'SkFx45lxlvA_000060', 'class': 'lions roaring', 'bbox': [[0.021875, 0.01875, 0.91875, 0.99375]]}
# {'file': 'xdcjFp3L0FE_000003', 'class': 'baltimore oriole calling', 'bbox': [[0.19375, 0.16875, 0.6875, 0.871875]]}
# {'file': 'r1am09HyMkA_000040', 'class': 'people booing', 'bbox': [[0.346875, 0.109375, 0.471875, 0.334375]]}
# {'file': 'So8G7UXguNA_000077', 'class': 'tractor digging', 'bbox': [[0.0, 0.009375, 1, 0.946875]]}
# {'file': '94PSD94IXXk_000016', 'class': 'chicken clucking', 'bbox': [[0.15625, 0.296875, 0.384375, 0.765625], [0.525, 0.0125, 0.7, 0.484375], [0.296875, 0.015625, 0.45, 0.36875], [0.86875, 0.29375, 0.990625, 0.775], [0.0, 0.215625, 0.10625, 0.34687500000000004]]}
# {'file': 'Iu1k5XJoeXk_000000', 'class': 'dog bow-wow', 'bbox': [[0.384375, 0.1875, 0.9375, 0.990625]]}
# {'file': 'Olfg9KK_bmE_000011', 'class': 'cricket chirping', 'bbox': [[0.184375, 0.1125, 0.934375, 0.8125]]}
# {'file': 'eUClW6xPg8I_000040', 'class': 'lighting firecrackers', 'bbox': [[0.44375, 0.78125, 0.559375, 0.93125]]}
# {'file': 'magdHwtSIjY_000031', 'class': 'missile launch', 'bbox': [[0.453125, 0.228125, 0.6125, 0.9375]]}
# {'file': 'RhsXiHgKzyY_000023', 'class': 'gibbon howling', 'bbox': [[0.03125, 0.0, 0.440625, 1]]}
# {'file': '1kTMiyc5eXg_000163', 'class': 'cricket chirping', 'bbox': [[0.028125, 0.134375, 0.98125, 0.95625]]}
# {'file': 'HJhFxiKjBoo_000030', 'class': 'horse clip-clop', 'bbox': [[0.63125, 0.403125, 0.7531249999999999, 0.66875]]}
# {'file': 'kQ7tkcg8Xag_000300', 'class': 'people marching', 'bbox': [[0.0, 0.134375, 0.9625, 0.9812500000000001]]}
# {'file': 'rrWsWt-rDrQ_000100', 'class': 'playing trombone', 'bbox': [[0.21875, 0.29375, 0.6875, 0.609375]]}
# {'file': '02UvvE1oA1I_000030', 'class': 'goat bleating', 'bbox': [[0.259375, 0.128125, 0.928125, 0.71875]]}
# {'file': 'MZFo739aKwI_000109', 'class': 'cow lowing', 'bbox': [[0.334375, 0.175, 0.640625, 0.95]]}
# {'file': 'zh4tznWde1M_000330', 'class': 'cat purring', 'bbox': [[0.375, 0.365625, 0.6, 0.725], [0.671875, 0.021875, 0.971875, 0.453125], [0.609375, 0.321875, 0.990625, 0.784375], [0.615625, 0.378125, 0.740625, 0.56875]]}
# {'file': '2xQuWif8axE_000030', 'class': 'playing electric guitar', 'bbox': [[0.45, 0.315625, 0.95, 0.6656249999999999]]}
# {'file': 'PNcdB7ptDis_000004', 'class': 'people finger snapping', 'bbox': [[0.20625, 0.065625, 0.984375, 0.99375]]}
# {'file': 'ddySWSpptVo_000122', 'class': 'wood thrush calling', 'bbox': [[0.275, 0.396875, 0.48125, 0.6375]]}
# {'file': 'K3CenN7d30Y_000030', 'class': 'chicken crowing', 'bbox': [[0.38125, 0.009375, 0.7906249999999999, 0.946875]]}
# {'file': 'RxhbTLS3rNo_000002', 'class': 'dog growling', 'bbox': [[0.23125, 0.00625, 0.675, 0.990625]]}
# {'file': 'S63LEKmzBis_000039', 'class': 'lathe spinning', 'bbox': [[0.05, 0.50625, 0.9750000000000001, 0.859375]]}
# {'file': '8FB9Cb00yTs_000065', 'class': 'mynah bird singing', 'bbox': [[0.184375, 0.096875, 0.715625, 0.9281250000000001]]}
# {'file': 'XB6j1Xabe3E_000470', 'class': 'bird wings flapping', 'bbox': [[0.034375, 0.15625, 0.984375, 0.446875]]}
# {'file': 'CDIex7WRfFo_000025', 'class': 'telephone bell ringing', 'bbox': [[0.34375, 0.0, 0.703125, 0.9875]]}
# {'file': 'aNkOcOCm32s_000010', 'class': 'dog howling', 'bbox': [[0.090625, 0.121875, 0.740625, 0.975]]}
# {'file': 'xiTI9orA7SA_000021', 'class': 'playing timbales', 'bbox': [[0.009375, 0.215625, 0.95625, 0.6156250000000001]]}
# {'file': 'Abezh6k-jOM_000030', 'class': 'car engine knocking', 'bbox': [[0.178125, 0.1625, 0.8875, 0.834375]]}
# {'file': '4z8HTrCvEsc_000097', 'class': 'tap dancing', 'bbox': [[0.7625, 0.6375, 0.84375, 0.725], [0.559375, 0.684375, 0.6749999999999999, 0.7749999999999999], [0.253125, 0.70625, 0.3625, 0.8031250000000001]]}
# {'file': 'xcATi4rdSu8_000002', 'class': 'wood thrush calling', 'bbox': [[0.484375, 0.64375, 0.6625, 0.99375]]}
# {'file': '6b-072VA4UA_000022', 'class': 'goat bleating', 'bbox': [[0.153125, 0.15, 0.903125, 0.9375]]}
# {'file': '3OlQmVVOzbQ_000250', 'class': 'rowboat, canoe, kayak rowing', 'bbox': [[0.359375, 0.4375, 0.878125, 0.778125]]}
# {'file': '9QjGgc1UkkU_000105', 'class': 'playing congas', 'bbox': [[0.00625, 0.5375, 0.196875, 0.6437499999999999], [0.215625, 0.54375, 0.4125, 0.63125], [0.421875, 0.5375, 0.6125, 0.690625], [0.634375, 0.6, 0.8187500000000001, 0.6906249999999999], [0.721875, 0.5125, 0.89375, 0.59375]]}
# {'file': 'x_5t0os3A2I_000009', 'class': 'playing bongo', 'bbox': [[0.009375, 0.240625, 0.796875, 0.99375]]}
# {'file': 'CQGQV-JxPoI_000030', 'class': 'cat meowing', 'bbox': [[0.221875, 0.0, 0.71875, 0.771875]]}
# {'file': '-rTTPoBJNI4_000123', 'class': 'playing tambourine', 'bbox': [[0.275, 0.24375, 0.59375, 0.890625]]}
# {'file': 'PrAm5YVvXx8_000010', 'class': 'dog howling', 'bbox': [[0.14375, 0.28125, 0.5, 0.91875]]}
# {'file': '2qHRJAQDCDo_000095', 'class': 'lathe spinning', 'bbox': [[0.31875, 0.375, 0.875, 0.715625]]}
# {'file': '1gSwLBNvEWE_000034', 'class': 'playing oboe', 'bbox': [[0.328125, 0.0, 0.796875, 0.296875]]}
# {'file': 'mhQGbJQlVns_000002', 'class': 'baby crying', 'bbox': [[0.3875, 0.190625, 0.675, 0.6625]]}
# {'file': 'Pyt8O3N6-wk_000110', 'class': 'dog growling', 'bbox': [[0.00625, 0.371875, 0.47812499999999997, 0.9875], [0.30625, 0.0, 0.546875, 0.6375]]}
# {'file': 'KiA1NLu5MCo_000001', 'class': 'snake hissing', 'bbox': [[0.215625, 0.05625, 0.671875, 0.565625]]}
# {'file': 'FwVYUHKoLtQ_000034', 'class': 'playing violin, fiddle', 'bbox': [[0.496875, 0.0625, 0.903125, 0.825]]}
# {'file': 'D668Jl6zuAk_000190', 'class': 'child speech, kid speaking', 'bbox': [[0, 0.31875, 0.809375, 0.7437499999999999]]}
# {'file': 'D1KdCkSFmnk_000000', 'class': 'people shuffling', 'bbox': [[0.35625, 0.278125, 0.690625, 0.9937499999999999]]}
# {'file': '_eLVrgvrVBQ_000020', 'class': 'vacuum cleaner cleaning floors', 'bbox': [[0.290625, 0.0, 0.9, 0.625]]}
# {'file': 'mjhlzNVpnXs_000026', 'class': 'air horn', 'bbox': [[0.075, 0.075, 0.9937499999999999, 0.953125]]}
# {'file': 'AJw-x30L46E_000080', 'class': 'playing acoustic guitar', 'bbox': [[0.028125, 0.14375, 0.959375, 0.878125]]}
# {'file': '1aDnyPubxdY_000118', 'class': 'baby crying', 'bbox': [[0.125, 0.096875, 0.71875, 0.99375]]}
# {'file': '3RSmQOcI9JI_000105', 'class': 'slot machine', 'bbox': [[0.146875, 0.075, 0.8468749999999999, 0.7281249999999999]]}
# {'file': 'B5u3PG7PWDE_000030', 'class': 'toilet flushing', 'bbox': [[0.334375, 0.25, 0.778125, 0.98125]]}
# {'file': 'C5enZKUmB4k_000030', 'class': 'lawn mowing', 'bbox': [[0.228125, 0.05625, 0.6875, 0.7875]]}
# {'file': 'mSHxFybELNY_000015', 'class': 'playing cornet', 'bbox': [[0.40625, 0.403125, 0.70625, 0.85625]]}
# {'file': 'bFTkrENAIzk_000237', 'class': 'popping popcorn', 'bbox': [[0.178125, 0.390625, 0.678125, 0.896875]]}
# {'file': 'eg-vJOCRwmo_000622', 'class': 'people eating noodle', 'bbox': [[0.365625, 0.009375, 0.815625, 0.325]]}
# {'file': 'IsGRLS6yPuE_000500', 'class': 'hair dryer drying', 'bbox': [[0.025, 0.065625, 0.9875, 0.7468750000000001]]}
# {'file': 'CjuYza6dsvs_000030', 'class': 'crow cawing', 'bbox': [[0.246875, 0.275, 0.846875, 0.9]]}
# {'file': 'K-PitCewkDg_000080', 'class': 'cheetah chirrup', 'bbox': [[0.234375, 0.025, 0.915625, 0.99375]]}
# {'file': 'WCC01d0hcBQ_000024', 'class': 'dinosaurs bellowing', 'bbox': [[0.040625, 0.30625, 0.725, 0.99375]]}
# {'file': 'NdqYvzceNo0_000001', 'class': 'playing shofar', 'bbox': [[0.4, 0.10625, 0.61875, 0.546875]]}
# {'file': 'GBifExKnaWI_000001', 'class': 'opening or closing car electric windows', 'bbox': [[0.01875, 0.1625, 0.8875000000000001, 0.990625]]}
# {'file': 'SZVguke6__M_000100', 'class': 'railroad car, train wagon', 'bbox': [[0.0, 0.075, 0.6375, 0.7625]]}
# {'file': 'hl6DOlVU-CQ_000024', 'class': 'telephone bell ringing', 'bbox': [[0.35, 0.01875, 0.64375, 0.9593750000000001]]}
# {'file': 'FMLhPfYb-oY_000030', 'class': 'lions roaring', 'bbox': [[0.5625, 0.490625, 0.796875, 0.9468749999999999]]}
# {'file': '3AzacBprTzU_000060', 'class': 'dog barking', 'bbox': [[0.0, 0.471875, 0.878125, 0.9906250000000001]]}
# {'file': 'MYv6qs-tjFY_000260', 'class': 'people hiccup', 'bbox': [[0.1375, 0.171875, 0.390625, 0.74375]]}
# {'file': '4K88ptVpPn8_000145', 'class': 'playing bugle', 'bbox': [[0.415625, 0.13125, 0.665625, 0.4375]]}
# {'file': 'nbS9NjA7Ywg_000078', 'class': 'squishing water', 'bbox': [[0.29375, 0.184375, 0.6937500000000001, 0.675]]}
# {'file': 'I7OqRsLtmh0_000310', 'class': 'church bell ringing', 'bbox': [[0.353125, 0.13125, 0.975, 0.7374999999999999]]}
# {'file': '3twm2ErD0kM_000154', 'class': 'playing cornet', 'bbox': [[0.46875, 0.3875, 0.625, 0.596875]]}
# {'file': 'v3nzRrcUBZk_000052', 'class': 'train wheels squealing', 'bbox': [[0.00625, 0.0, 0.99375, 0.825]]}
# {'file': 'bkFvzo2HSrU_000032', 'class': 'playing congas', 'bbox': [[0.4625, 0.7, 0.6781250000000001, 0.865625], [0.234375, 0.753125, 0.446875, 0.875]]}
# {'file': 'ueKKohFYF8g_000000', 'class': 'telephone bell ringing', 'bbox': [[0.371875, 0.028125, 0.571875, 0.959375]]}
# {'file': 'mEL68q2FRBo_000100', 'class': 'child singing', 'bbox': [[0.44375, 0.775, 0.559375, 0.9]]}
# {'file': 'f1mXMVWFLiA_000183', 'class': 'people eating apple', 'bbox': [[0.234375, 0.065625, 0.50625, 0.35625]]}
# {'file': 'dfwr8wgZU8M_000040', 'class': 'car passing by', 'bbox': [[0.45, 0.51875, 0.596875, 0.696875]]}
# {'file': '799dPLm5vs4_000002', 'class': 'pheasant crowing', 'bbox': [[0.171875, 0.353125, 0.675, 0.8562500000000001]]}
# {'file': 'raIIQCRNwu0_000080', 'class': 'playing accordion', 'bbox': [[0.615625, 0.36875, 0.975, 0.9343750000000001]]}
# {'file': 'kH6fFjIZkB0_000030', 'class': 'reversing beeps', 'bbox': [[0.353125, 0.0125, 0.8875000000000001, 0.56875]]}
# {'file': 'XdNW5tS4u3w_000014', 'class': 'playing tambourine', 'bbox': [[0.209375, 0.678125, 0.5375, 0.95]]}
# {'file': '2eYaXTKSpMI_000004', 'class': 'cat meowing', 'bbox': [[0.134375, 0.4, 0.6843750000000001, 0.99375]]}
# {'file': 'hmD1w6133Og_000110', 'class': 'machine gun shooting', 'bbox': [[0.071875, 0.278125, 0.6625, 0.971875]]}
# {'file': 'MetDvJdgZ64_000049', 'class': 'lions growling', 'bbox': [[0.13125, 0.1375, 0.603125, 0.875]]}
# {'file': '2p37j052q3o_000004', 'class': 'alarm clock ringing', 'bbox': [[0.20625, 0.03125, 0.7718750000000001, 0.990625]]}
# {'file': 'qbRZ67ynqp0_000050', 'class': 'people belly laughing', 'bbox': [[0.525, 0.265625, 0.659375, 0.46875], [0.33125, 0.303125, 0.4375, 0.55]]}
# {'file': 'EQKs1YLMUuI_000004', 'class': 'playing oboe', 'bbox': [[0.478125, 0.29375, 0.703125, 0.9875]]}
# {'file': 'TUpX4p-Ej_o_000336', 'class': 'train wheels squealing', 'bbox': [[0.025, 0.30625, 0.99375, 0.9187500000000001]]}
# {'file': 'n7t58h1fwc0_000168', 'class': 'playing cornet', 'bbox': [[0.396875, 0.315625, 0.5031249999999999, 0.521875]]}
# {'file': '_1vudgh5RpE_000059', 'class': 'airplane flyby', 'bbox': [[0.290625, 0.4, 0.434375, 0.534375], [0.4375, 0.39375, 0.553125, 0.540625], [0.553125, 0.359375, 0.6593749999999999, 0.515625]]}
# {'file': 'BbWdsbZ9TsM_000130', 'class': 'subway, metro, underground', 'bbox': [[0.059375, 0.29375, 0.9937499999999999, 0.640625]]}
# {'file': 'AHIV0RMwnN8_000210', 'class': 'tap dancing', 'bbox': [[0.35625, 0.603125, 0.51875, 0.84375]]}
# {'file': '6zTszR6wgys_000200', 'class': 'railroad car, train wagon', 'bbox': [[0, 0.334375, 0.725, 0.99375]]}
# {'file': '2f7NnTVQzR0_000150', 'class': 'female singing', 'bbox': [[0.39375, 0.065625, 0.7281249999999999, 0.49374999999999997]]}
# {'file': 'y9_9tveI1OY_000100', 'class': 'people sneezing', 'bbox': [[0.36875, 0.346875, 0.5875, 0.659375]]}
# {'file': 'HJg4jZNv1pc_000150', 'class': 'people coughing', 'bbox': [[0.2, 0.19375, 0.309375, 0.375], [0.621875, 0.009375, 0.7281249999999999, 0.19999999999999998]]}
# {'file': 'NgAEMX5d5iM_000083', 'class': 'train wheels squealing', 'bbox': [[0, 0.146875, 0.996875, 0.671875]]}
# {'file': '0bobzCB2ObQ_000076', 'class': 'tractor digging', 'bbox': [[0.0125, 0.0, 0.9312499999999999, 0.99375]]}
# {'file': 'GWTZtu3NOCc_000030', 'class': 'singing choir', 'bbox': [[0.00625, 0.10625, 0.775, 0.803125]]}
# Converted 5158 records from 'data_set_try1/dataset/vggss.json' → 'data_set_try1/dataset/vggss.csv'.

# %%
import os
import cv2
import json
import torch
import csv
import pandas as pd
import numpy as np
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import pdb
import time
from PIL import Image
import glob
import sys 
import scipy.io.wavfile as wav
from scipy import signal
import random
import soundfile as sf



class GetAudioVideoDataset(Dataset):

    def __init__(self, args, mode='train', transforms=None):
 
        data = []
        if args.testset == 'flickr':
            testcsv = 'metadata/flickr_test.csv'
        elif args.testset == 'vggss':
            testcsv = 'metadata/vggss_test.csv'

        with open(testcsv) as f:
            csv_reader = csv.reader(f)
            for item in csv_reader:
                data.append(item[0] + '.mp4')
        self.audio_path = args.data_path + 'audio/'
        self.video_path = args.data_path + 'frames/'

        self.imgSize = args.image_size 

        self.mode = mode
        self.transforms = transforms
        # initialize video transform
        self._init_atransform()
        self._init_transform()
        #  Retrieve list of audio and video files
        self.video_files = []
   
        for item in data[:]:
            self.video_files.append(item )
        print(len(self.video_files))
        self.count = 0

    def _init_transform(self):
        mean = [0.485, 0.456, 0.406]
        std = [0.229, 0.224, 0.225]
        if self.mode == 'train':
            self.img_transform = transforms.Compose([
                transforms.Resize(int(self.imgSize * 1.1), Image.BICUBIC),
                transforms.RandomCrop(self.imgSize),
                transforms.RandomHorizontalFlip(),
                transforms.CenterCrop(self.imgSize),
                transforms.ToTensor(),
                transforms.Normalize(mean, std)])
        else:
            self.img_transform = transforms.Compose([
                transforms.Resize(self.imgSize, Image.BICUBIC),
                transforms.CenterCrop(self.imgSize),
                transforms.ToTensor(),
                transforms.Normalize(mean, std)])            

    def _init_atransform(self):
        self.aid_transform = transforms.Compose([transforms.ToTensor(),transforms.Normalize(mean=[0.0], std=[12.0])])
#  

    def _load_frame(self, path):
        img = Image.open(path).convert('RGB')
        return img

    def __len__(self):
        # Consider all positive and negative examples
        return len(self.video_files)  # self.length

    def __getitem__(self, idx):
        file = self.video_files[idx]

        # Image
        frame = self.img_transform(self._load_frame(self.video_path + file[:-3] + 'jpg'))
        frame_ori = np.array(self._load_frame(self.video_path  + file[:-3] + 'jpg'))
        # Audio
        samples, samplerate = sf.read(self.audio_path + file[:-3]+'wav')

        # repeat if audio is too short
        if samples.shape[0] < samplerate * 10:
            n = int(samplerate * 10 / samples.shape[0]) + 1
            samples = np.tile(samples, n)
        resamples = samples[:samplerate*10]

        resamples[resamples > 1.] = 1.
        resamples[resamples < -1.] = -1.
        frequencies, times, spectrogram = signal.spectrogram(resamples,samplerate, nperseg=512,noverlap=274)
        spectrogram = np.log(spectrogram+ 1e-7)
        spectrogram = self.aid_transform(spectrogram)
 

        return frame,spectrogram,resamples,file,torch.tensor(frame_ori)
